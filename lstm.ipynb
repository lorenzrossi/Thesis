# %%
import datetime
import pandas as pd
import os
import numpy as np
from matplotlib import pyplot
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import seaborn as sns
import statsmodels.api as sm
import warnings

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller, kpss, ccf
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA 

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
os.chdir('C:\\Users\\loren\\OneDrive - Università degli Studi di Milano\\Lezioni uni\\Tesi\\Dataset Energia\\')
path = 'Italy'

# %%
df2016 = pd.read_csv(os.path.join(path, f"ITA2016.csv"), parse_dates = ['MTU'])
df2017 = pd.read_csv(os.path.join(path, f"ITA2017.csv"), parse_dates = ['MTU'])
df2018 = pd.read_csv(os.path.join(path, f"ITA2018.csv"), parse_dates = ['MTU'])
df2019 = pd.read_csv(os.path.join(path, f"ITA2019.csv"), parse_dates = ['MTU'])
df2020 = pd.read_csv(os.path.join(path, f"ITA2020.csv"), parse_dates = ['MTU'])
df2021 = pd.read_csv(os.path.join(path, f"ITA2021.csv"), parse_dates = ['MTU'])

# %%
def retrieve_data(path):
    # creo il vettore degli anni e il df vuoto dove appendere i singoli df
    years = [2016, 2017, 2018, 2019, 2020, 2021]
    tot = pd.DataFrame()
    
    # carico i dati dei diversi anni
    for year in years:
        df = pd.read_csv(os.path.join(path, f"ITA{year}.csv"), parse_dates = ['MTU'])
        #df = df.reset_index()
        
        # aggiusto il formato della data in YYYY-MM-DD HH:mm
        for i, row in df.iterrows():
            df["MTU"][i] = df['MTU'][i][:16]
        
        df['Time'] = pd.to_datetime(df['MTU'], utc=True, infer_datetime_format=True)
        df.Time = df.Time.dt.strftime('%Y-%m-%d')
        df = df.set_index(pd.DatetimeIndex(df['Time']))

        # elimino colonne con solo NA
        df = df.drop(columns=['MTU','Area','Fossil Brown coal/Lignite  - Actual Aggregated [MW]','Fossil Oil shale  - Actual Aggregated [MW]',
                     'Fossil Peat  - Actual Aggregated [MW]', 'Marine  - Actual Aggregated [MW]', 'Nuclear  - Actual Aggregated [MW]',
                     'Wind Offshore  - Actual Aggregated [MW]', 'Other renewable  - Actual Aggregated [MW]'])
        
        # appendo i vari df a quello vuoto principale
        tot = pd.concat([tot, df], ignore_index=True)
    
    # imposto la data come indice
    tot = tot.set_index(pd.DatetimeIndex(tot['Time']))
    return tot

# %%
data = retrieve_data(path)
# Out:
# C:\Users\loren\AppData\Local\Temp\ipykernel_5624\2564700696.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\loren\AppData\Local\Temp\ipykernel_5624\2564700696.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\loren\AppData\Local\Temp\ipykernel_5624\2564700696.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\loren\AppData\Local\Temp\ipykernel_5624\2564700696.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\loren\AppData\Local\Temp\ipykernel_5624\2564700696.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\loren\AppData\Local\Temp\ipykernel_5624\2564700696.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print('There are {} missing values or NaNs in df_final.'.format(data.isnull().values.sum()))
# Out:
# There are 17584 missing values or NaNs in df_final.

# %%
data.interpolate(method='linear', limit_direction='forward', inplace=True, axis=0)

# %%
data.describe()
# Out:
#        Biomass  - Actual Aggregated [MW]  \
# count                       52614.000000
# mean                          491.304482
# std                           165.546821
# min                           167.000000
# 25%                           334.000000
# 50%                           481.000000
# 75%                           652.000000
# max                           845.000000
#
#        Fossil Coal-derived gas  - Actual Aggregated [MW]  \
# count                                       52614.000000
# mean                                          411.358526
# std                                           241.377903
# min                                             0.000000
# 25%                                           232.000000
# 50%                                           280.000000
# 75%                                           592.000000
# max                                          1135.000000
#
#        Fossil Gas  - Actual Aggregated [MW]  \
# count                          52614.000000
# mean                           10398.377352
# std                             4702.358879
# min                             1590.000000
# 25%                             6674.000000
# 50%                             9641.000000
# 75%                            13422.750000
# max                            27688.000000
#
#        Fossil Hard coal  - Actual Aggregated [MW]  \
# count                                52614.000000
# mean                                  1876.884736
# std                                    967.511420
# min                                    204.000000
# 25%                                   1170.000000
# 50%                                   1582.000000
# 75%                                   2452.000000
# max                                   6198.000000
#
#        Fossil Oil  - Actual Aggregated [MW]  \
# count                          52614.000000
# mean                             135.662457
# std                              116.660972
# min                                0.000000
# 25%                               39.000000
# 50%                               93.000000
# 75%                              209.000000
# max                              783.000000
#
#        Geothermal  - Actual Aggregated [MW]  \
# count                          52614.000000
# mean                             650.406812
# std                               22.489450
# min                              485.000000
# 25%                              637.000000
# 50%                              653.000000
# 75%                              667.000000
# max                              707.000000
#
#        Hydro Pumped Storage  - Actual Aggregated [MW]  \
# count                                    52614.000000
# mean                                       380.245800
# std                                        518.017544
# min                                          0.000000
# 25%                                          5.000000
# 50%                                        167.000000
# 75%                                        542.000000
# max                                       4526.000000
#
#        Hydro Pumped Storage  - Actual Consumption [MW]  \
# count                                     52614.000000
# mean                                        285.435816
# std                                         422.781559
# min                                           1.000000
# 25%                                          25.000000
# 50%                                         112.750000
# 75%                                         349.000000
# max                                        3974.000000
#
#        Hydro Run-of-river and poundage  - Actual Aggregated [MW]  \
# count                                       52614.000000
# mean                                         3818.574676
# std                                          1577.662605
# min                                           774.000000
# 25%                                          2540.000000
# 50%                                          3691.000000
# 75%                                          4975.000000
# max                                          8534.000000
#
#        Hydro Water Reservoir  - Actual Aggregated [MW]  \
# count                                     52614.000000
# mean                                        789.196203
# std                                         489.626447
# min                                          14.000000
# 25%                                         402.000000
# 50%                                         708.000000
# 75%                                        1115.000000
# max                                        2872.000000
#
#        Other  - Actual Aggregated [MW]  Solar  - Actual Aggregated [MW]  \
# count                     52614.000000                     52614.000000
# mean                       5584.579665                      2185.143498
# std                        3856.001692                      3040.677333
# min                         623.000000                         0.000000
# 25%                        2222.000000                         0.000000
# 50%                        4079.500000                        60.000000
# 75%                        8445.750000                      4178.000000
# max                       19489.000000                     11812.000000
#
#        Waste  - Actual Aggregated [MW]  Wind Onshore  - Actual Aggregated [MW]
# count                     52614.000000                            52614.000000
# mean                         37.795957                             2114.967784
# std                           8.574162                             1525.440236
# min                           5.000000                               20.000000
# 25%                          32.000000                              858.000000
# 50%                          39.000000                             1753.000000
# 75%                          44.000000                             3084.000000
# max                          62.000000                             7611.000000

# %% [markdown]
# Appunto: TERNA informs the platform users that from 27th June 2017 the category “Other” has been redistributed to the correct Types.
# TERNA informs the platform users that actual data is reported on a provisional basis. Provisional data can be subject to adjustments and recalculations.
# Cacchio vuol dire? Mannaggiatterna

# %%
def daily_data_and_aggregator(df):

    # seleziono tutte le colonne delle fonti energetiche
    columns = df.columns[ : data.shape[1]-1]

    # aggrego giornalmente i dati
    daily_df = pd.DataFrame(df[columns].groupby([pd.Grouper(level='Time', freq='D')]).sum())

    # creo l'aggregato totale
    daily_df['total_aggregated'] = daily_df[columns].sum(axis=1)

    return daily_df

# %%
daily_data = daily_data_and_aggregator(data)

# %%
daily_data.total_aggregated.describe()
# Out:
# count      2192.000000
# mean     699918.227646
# std      103382.026351
# min      459101.000000
# 25%      614134.500000
# 50%      708275.986111
# 75%      776133.742424
# max      978987.375000
# Name: total_aggregated, dtype: float64

# %%
# creo due dunzioni: una per i weekend (quando sabato/domenica è 1, altrimenti 0) e l'altra per le vacanze (1/1, 25/4, 1/5, 2/6, 15/8, 25/12)
def weekend_generation(df):
    # Generate 'weekend' feature
    for i in range(len(df)):
        position = df.index[i]
        hour = position.hour
        weekend = position.weekday()
        month = position.month
        df.loc[position, 'weekend'] = weekend

    for i in range(len(df)):
        position = df.index[i]
        weekend = position.weekday()
        if (weekend >= 5):
            df.loc[position, 'weekend'] = 1
        else:
            df.loc[position, 'weekend'] = 0
    return df

# %%
daily_data2 = weekend_generation(daily_data)

# %%
daily_data2['total_aggregated'].plot()
# Out:
# <AxesSubplot: xlabel='Time'>

# %% [markdown]
# # ARIMA: AR(1)

# %%
# Facciamo test di stazionarietà classico col DF
df_stationarityTest = adfuller(daily_data['total_aggregated'], autolag='AIC')

# Check del p-value: è decisamente sotto 0.05, quindi la serie è stazionaria, no unit root
print("P-value: ", df_stationarityTest[1])
# Out:
# P-value:  6.441636980544729e-10

# %%
# Ora trovare l'ordine del nostro AR
# Plotto il grafico delle autocorrelazioni per determinare
# quando decade la dipendenza col passato
from statsmodels.graphics.tsaplots import plot_pacf
pacf = plot_pacf(daily_data['total_aggregated'], lags=25, method='ywm')

# dal grafico si nota che la dipendenza col passato decade dopo il primo lag, quindi useremo un AR(1)

# %%
# splitto il dataframe in train e test. dovendo usare gli ultimi due anni come test set, 
# utilizzo per quest'ultimo le ultime 730 osservazioni (365*2)
series = daily_data['total_aggregated']
X = series.values

# %%
train, test = X[0:len(X)-730], X[len(X)-730:]

# %%
model = ARIMA(series, order=(1,0,0))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       total_aggregated   No. Observations:                 2192
# Model:                 ARIMA(1, 0, 0)   Log Likelihood              -28245.412
# Date:                Thu, 23 Feb 2023   AIC                          56496.824
# Time:                        09:10:59   BIC                          56513.901
# Sample:                    01-01-2016   HQIC                         56503.065
#                          - 12-31-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.999e+05   3308.295    211.565      0.000    6.93e+05    7.06e+05
# ar.L1          0.3835      0.018     21.054      0.000       0.348       0.419
# sigma2      9.103e+09      0.001   7.99e+12      0.000     9.1e+09     9.1e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.82   Jarque-Bera (JB):                27.08
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                            -0.01
# Prob(H) (two-sided):                  0.77   Kurtosis:                         2.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.16e+28. Standard errors may be unstable.

# %%
# train autoregression
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(1,0,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=641045.513893, expected=619526.400000
# predicted=676336.504330, expected=501058.000000
# predicted=634631.404697, expected=622421.000000
# predicted=677121.283955, expected=557044.666667
# predicted=654029.530998, expected=604723.500000
# predicted=670687.648697, expected=813048.633929
# predicted=743929.477486, expected=758877.000000
# predicted=724949.826137, expected=846902.333333
# predicted=755965.847559, expected=702444.500000
# predicted=705202.889182, expected=485780.000000
# predicted=629060.849056, expected=784734.000000
# predicted=733847.728594, expected=779109.000000
# predicted=731934.579567, expected=808540.500000
# predicted=742287.128393, expected=808441.000000
# predicted=742341.402118, expected=792847.000000
# predicted=736953.365395, expected=786202.000000
# predicted=734683.454140, expected=640239.500000
# predicted=683544.003878, expected=561098.000000
# predicted=655712.010155, expected=800518.000000
# predicted=739524.100641, expected=846101.000000
# predicted=755586.020538, expected=848347.000000
# predicted=756550.659647, expected=881180.500000
# predicted=768332.789399, expected=851294.500000
# predicted=758019.047982, expected=653500.000000
# predicted=688307.158098, expected=566673.500000
# predicted=657656.800245, expected=783100.000000
# predicted=733795.955469, expected=812311.500000
# predicted=744132.624890, expected=807338.500000
# predicted=742471.591506, expected=784377.000000
# predicted=734449.638427, expected=749750.600000
# predicted=722283.131218, expected=608141.500000
# predicted=672415.133129, expected=529710.500000
# predicted=644589.592926, expected=714918.000000
# predicted=709901.545553, expected=566688.000000
# predicted=657693.821966, expected=571998.000000
# predicted=659400.211215, expected=605655.500000
# predicted=671175.986240, expected=833450.437500
# predicted=751514.409803, expected=654967.000000
# predicted=688710.377015, expected=837528.666667
# predicted=752818.875259, expected=688885.500000
# predicted=700689.708404, expected=632107.000000
# predicted=680768.450399, expected=868381.500000
# predicted=763453.015860, expected=751109.500000
# predicted=722494.740228, expected=739861.000000
# predicted=718581.938146, expected=583480.000000
# predicted=663939.656546, expected=492314.000000
# predicted=631741.520670, expected=702745.000000
# predicted=705469.149363, expected=733814.500000
# predicted=716336.114250, expected=748812.500000
# predicted=721596.574083, expected=741975.500000
# predicted=719224.357657, expected=724714.000000
# predicted=713199.333369, expected=592155.000000
# predicted=666834.750471, expected=508837.500000
# predicted=637415.255071, expected=699484.000000
# predicted=704241.937098, expected=722775.000000
# predicted=712394.541513, expected=735907.500000
# predicted=717000.595269, expected=723074.500000
# predicted=712519.268562, expected=710949.000000
# predicted=708279.877695, expected=554584.000000
# predicted=653529.186635, expected=613098.000000
# predicted=673917.215398, expected=728194.500000
# predicted=714216.503996, expected=724530.000000
# predicted=712942.530379, expected=550311.000000
# predicted=651960.494057, expected=560206.785714
# predicted=655227.026368, expected=699822.500000
# predicted=704165.621006, expected=812449.730769
# predicted=743638.678825, expected=813339.000000
# predicted=744044.358970, expected=798420.500000
# predicted=738886.998443, expected=590654.500000
# predicted=666032.365858, expected=664145.000000
# predicted=691738.862941, expected=829792.000000
# predicted=749732.651543, expected=580356.500000
# predicted=662616.022558, expected=494318.500000
# predicted=632270.740474, expected=503691.000000
# predicted=635120.832742, expected=582150.000000
# predicted=662557.121167, expected=568112.000000
# predicted=657456.881836, expected=562853.500000
# predicted=655426.334768, expected=555843.000000
# predicted=652752.781718, expected=539516.500000
# predicted=646722.197514, expected=459101.000000
# predicted=617558.710192, expected=459592.000000
# predicted=617046.858927, expected=601997.000000
# predicted=668218.507676, expected=553570.000000
# predicted=650610.955287, expected=565695.000000
# predicted=654818.052437, expected=566848.000000
# predicted=655074.743340, expected=540099.000000
# predicted=645157.216268, expected=497722.000000
# predicted=629374.158907, expected=507666.500000
# predicted=632620.317356, expected=541409.000000
# predicted=644734.447034, expected=569665.000000
# predicted=654958.824717, expected=561985.222222
# predicted=651966.879114, expected=750836.000000
# predicted=721595.580300, expected=694943.000000
# predicted=701026.015958, expected=572557.000000
# predicted=655938.557132, expected=633122.839286
# predicted=678182.517380, expected=694055.500000
# predicted=700610.769436, expected=625484.769231
# predicted=675336.071079, expected=799687.000000
# predicted=739445.958093, expected=786393.404762
# predicted=734615.223078, expected=507384.500000
# predicted=632135.410868, expected=663517.000000
# predicted=689385.542663, expected=786868.000000
# predicted=734585.071663, expected=521651.000000
# predicted=637611.555740, expected=579026.000000
# predicted=658424.878256, expected=597249.500000
# predicted=664996.719824, expected=579823.000000
# predicted=658499.033595, expected=575309.000000
# predicted=656713.050285, expected=546723.500000
# predicted=646019.051827, expected=527121.000000
# predicted=638536.661956, expected=613021.000000
# predicted=670192.338747, expected=609840.000000
# predicted=668949.051368, expected=602370.000000
# predicted=666108.697727, expected=597851.000000
# predicted=664350.515569, expected=601416.500000
# predicted=665591.082033, expected=579114.714286
# predicted=657203.384263, expected=558802.071429
# predicted=649495.712793, expected=611695.214286
# predicted=669117.798317, expected=617389.500000
# predicted=671181.204928, expected=636972.000000
# predicted=678444.276769, expected=627106.333333
# predicted=674719.181865, expected=551671.777778
# predicted=646424.732017, expected=767983.000000
# predicted=727224.510447, expected=702668.000000
# predicted=702884.006141, expected=548699.000000
# predicted=645458.536074, expected=613400.375000
# predicted=669503.122520, expected=683583.500000
# predicted=695665.455912, expected=584253.200000
# predicted=658574.702663, expected=740899.500000
# predicted=716983.414195, expected=611146.595238
# predicted=668656.306999, expected=650845.000000
# predicted=683402.941682, expected=630293.000000
# predicted=675713.248071, expected=640838.500000
# predicted=679606.550604, expected=667549.500000
# predicted=689541.362973, expected=652580.000000
# predicted=683940.953242, expected=663166.000000
# predicted=687867.746505, expected=593758.071429
# predicted=661933.804852, expected=552053.178571
# predicted=646218.058736, expected=653580.250000
# predicted=684132.992941, expected=685992.500000
# predicted=696233.936164, expected=686763.875000
# predicted=696515.837140, expected=677037.458333
# predicted=692872.259699, expected=636875.766667
# predicted=677838.438657, expected=585631.900000
# predicted=658605.033946, expected=567592.000000
# predicted=651722.731458, expected=671375.625000
# predicted=690594.080814, expected=710954.175000
# predicted=705417.737856, expected=708440.200000
# predicted=704478.923238, expected=677367.000000
# predicted=692834.994927, expected=640580.500000
# predicted=679033.090144, expected=586666.500000
# predicted=658760.053923, expected=566442.000000
# predicted=651043.306438, expected=601545.000000
# predicted=664144.448735, expected=769973.000000
# predicted=727428.510759, expected=699549.000000
# predicted=701004.015615, expected=551823.000000
# predicted=645530.863364, expected=611075.500000
# predicted=667695.576301, expected=585172.500000
# predicted=657875.720449, expected=758181.133333
# predicted=722885.100131, expected=755253.500000
# predicted=721813.015993, expected=582636.000000
# predicted=657037.940455, expected=681939.500000
# predicted=694257.901750, expected=654779.000000
# predicted=684061.200758, expected=602677.500000
# predicted=664477.547821, expected=613578.500000
# predicted=668505.502904, expected=610616.000000
# predicted=667332.311837, expected=748590.000000
# predicted=719143.837002, expected=798148.750000
# predicted=737791.377417, expected=834096.750000
# predicted=751405.078763, expected=816963.500000
# predicted=745067.154230, expected=749983.500000
# predicted=719878.993378, expected=618754.200000
# predicted=670477.610888, expected=602760.133333
# predicted=664392.501023, expected=752847.666667
# predicted=720883.600076, expected=805352.000000
# predicted=740686.659306, expected=814281.111111
# predicted=744137.669510, expected=790247.013889
# predicted=735146.097447, expected=753914.875000
# predicted=721476.936028, expected=634922.227273
# predicted=676608.028704, expected=586395.472727
# predicted=658242.061163, expected=785171.911111
# predicted=733160.806524, expected=801465.317460
# predicted=739361.533483, expected=724959.000000
# predicted=710557.708971, expected=762979.000000
# predicted=724899.528325, expected=549038.500000
# predicted=644372.641245, expected=569557.000000
# predicted=651950.277558, expected=640457.625000
# predicted=678623.293227, expected=587642.500000
# predicted=658648.973158, expected=820441.166667
# predicted=746336.238539, expected=761042.000000
# predicted=724032.974830, expected=782165.500000
# predicted=732022.766726, expected=711928.500000
# predicted=705598.751754, expected=560012.000000
# predicted=648412.045856, expected=762565.500000
# predicted=724554.880700, expected=750834.833333
# predicted=720177.008824, expected=776159.969697
# predicted=729719.886569, expected=818458.363636
# predicted=745686.493827, expected=829757.500000
# predicted=750051.612977, expected=800164.500000
# predicted=738987.244559, expected=647977.666667
# predicted=681665.840869, expected=564720.833333
# predicted=650244.712452, expected=742933.000000
# predicted=717336.293689, expected=810675.500000
# predicted=742860.248960, expected=816760.000000
# predicted=745243.368833, expected=824525.500000
# predicted=748275.757643, expected=784708.333333
# predicted=733315.775062, expected=654700.666667
# predicted=684268.060648, expected=570737.500000
# predicted=652533.439370, expected=776323.000000
# predicted=730040.571525, expected=812505.285714
# predicted=743734.679031, expected=826921.714286
# predicted=749275.235517, expected=854412.000000
# predicted=759811.815939, expected=878398.000000
# predicted=769119.315704, expected=764217.000000
# predicted=725876.437349, expected=596919.000000
# predicted=662503.872855, expected=520265.000000
# predicted=633277.258196, expected=560933.500000
# predicted=648544.059376, expected=616270.875000
# predicted=669517.471648, expected=728378.142857
# predicted=712146.790852, expected=826331.500000
# predicted=749430.810800, expected=660618.000000
# predicted=686450.280711, expected=796564.000000
# predicted=738052.923420, expected=687241.000000
# predicted=696590.906105, expected=486041.500000
# predicted=620222.446640, expected=760260.000000
# predicted=724117.839751, expected=755233.857143
# predicted=722245.502127, expected=759876.642857
# predicted=724026.135986, expected=649973.000000
# predicted=682510.407373, expected=601467.200000
# predicted=664141.196783, expected=739899.300000
# predicted=716422.479393, expected=749128.944444
# predicted=719924.927162, expected=730343.555556
# predicted=712847.796770, expected=735294.875000
# predicted=714729.505448, expected=702346.625000
# predicted=702295.214207, expected=637499.000000
# predicted=677800.108143, expected=588115.500000
# predicted=659085.787329, expected=782114.300000
# predicted=732324.072630, expected=796337.033333
# predicted=737745.961997, expected=814147.666667
# predicted=744549.539302, expected=872180.000000
# predicted=766658.332863, expected=813811.625000
# predicted=744662.740295, expected=683540.875000
# predicted=695313.203605, expected=633978.500000
# predicted=676527.007402, expected=803945.500000
# predicted=740849.744138, expected=781267.000000
# predicted=732323.119630, expected=524826.000000
# predicted=635418.159895, expected=663676.500000
# predicted=687810.561567, expected=543426.500000
# predicted=642360.053442, expected=581058.000000
# predicted=656452.507091, expected=770793.857143
# predicted=728130.575271, expected=855156.500000
# predicted=760077.363062, expected=611997.000000
# predicted=668330.602631, expected=803465.500000
# predicted=740367.466896, expected=678599.500000
# predicted=693451.690612, expected=658724.000000
# predicted=685972.903081, expected=881856.000000
# predicted=769723.904160, expected=605740.500000
# predicted=666312.661315, expected=794763.000000
# predicted=736854.633494, expected=865626.000000
# predicted=763428.398632, expected=837592.000000
# predicted=753101.099053, expected=819089.500000
# predicted=746280.450488, expected=819858.000000
# predicted=746665.398377, expected=657278.000000
# predicted=685718.802933, expected=583564.000000
# predicted=658049.931206, expected=795601.375000
# predicted=737432.536789, expected=804666.625000
# predicted=740891.964419, expected=811817.714286
# predicted=743649.185726, expected=778816.285714
# predicted=731335.017783, expected=777227.500000
# predicted=730780.691102, expected=609244.000000
# predicted=667824.219300, expected=536847.500000
# predicted=640551.512710, expected=731800.500000
# predicted=713650.380015, expected=781084.000000
# predicted=732129.002555, expected=737794.500000
# predicted=715938.758144, expected=783936.500000
# predicted=733250.911851, expected=748108.000000
# predicted=719853.704245, expected=669270.500000
# predicted=690318.915889, expected=554352.000000
# predicted=647202.747923, expected=541300.000000
# predicted=642117.460816, expected=805421.000000
# predicted=741186.108558, expected=816616.500000
# predicted=745462.489502, expected=718295.000000
# predicted=708644.519050, expected=804118.000000
# predicted=740814.861400, expected=571352.750000
# predicted=653740.149012, expected=671555.500000
# predicted=691156.902953, expected=861348.000000
# predicted=762028.603674, expected=726857.500000
# predicted=711855.696154, expected=691241.666667
# predicted=698575.293220, expected=738290.333333
# predicted=716124.177669, expected=716203.000000
# predicted=707896.564704, expected=587746.500000
# predicted=659986.993747, expected=526410.000000
# predicted=636922.044494, expected=684421.500000
# predicted=695934.670810, expected=681649.666667
# predicted=694892.897228, expected=668069.333333
# predicted=689813.648108, expected=700913.500000
# predicted=702065.716665, expected=680267.000000
# predicted=694355.786160, expected=546898.500000
# predicted=644521.204620, expected=532426.000000
# predicted=638900.132668, expected=659569.000000
# predicted=686463.447211, expected=690377.000000
# predicted=697980.252777, expected=686047.500000
# predicted=696355.243357, expected=691901.000000
# predicted=698540.414183, expected=667825.000000
# predicted=689523.924463, expected=530327.000000
# predicted=637990.324358, expected=620960.000000
# predicted=671870.617052, expected=756924.000000
# predicted=722779.307801, expected=658895.500000
# predicted=686103.027350, expected=556376.500000
# predicted=647677.867118, expected=620518.500000
# predicted=671632.316009, expected=717368.000000
# predicted=707894.193499, expected=654072.833333
# predicted=684194.760537, expected=759603.500000
# predicted=723688.033600, expected=784874.000000
# predicted=733182.637330, expected=530094.250000
# predicted=637952.007118, expected=681811.000000
# predicted=694580.980653, expected=776363.000000
# predicted=729854.005152, expected=683692.000000
# predicted=695306.951932, expected=563251.000000
# predicted=650366.451787, expected=504517.000000
# predicted=628193.999348, expected=681155.000000
# predicted=694222.217811, expected=700169.500000
# predicted=701318.316958, expected=702676.500000
# predicted=702254.218659, expected=696325.000000
# predicted=699881.712827, expected=713348.000000
# predicted=706238.988788, expected=607236.500000
# predicted=666608.776299, expected=554321.000000
# predicted=646728.119084, expected=702220.500000
# predicted=702001.173071, expected=715130.500000
# predicted=706824.962656, expected=707830.000000
# predicted=704101.861862, expected=724768.000000
# predicted=710432.780622, expected=732620.000000
# predicted=713375.460652, expected=616696.500000
# predicted=670082.247205, expected=566832.500000
# predicted=651364.845201, expected=758578.000000
# predicted=722983.158310, expected=579931.000000
# predicted=656381.513999, expected=750969.000000
# predicted=720069.644539, expected=613846.500000
# predicted=669077.066690, expected=529428.500000
# predicted=637539.707003, expected=653528.000000
# predicted=683719.762654, expected=671924.500000
# predicted=690553.046223, expected=592698.000000
# predicted=661019.457804, expected=757065.000000
# predicted=722191.947333, expected=653345.000000
# predicted=683633.339704, expected=708657.500000
# predicted=704183.261325, expected=699673.000000
# predicted=700845.555951, expected=634184.000000
# predicted=676497.606708, expected=604015.500000
# predicted=665233.266381, expected=752447.000000
# predicted=720398.078658, expected=771081.500000
# predicted=727349.538604, expected=780346.500000
# predicted=730832.926932, expected=774342.000000
# predicted=728640.164795, expected=763768.500000
# predicted=724739.350527, expected=585577.000000
# predicted=658485.560655, expected=514988.500000
# predicted=632039.628518, expected=678184.000000
# predicted=692799.967506, expected=692464.000000
# predicted=698106.887642, expected=651614.000000
# predicted=682898.452459, expected=515964.500000
# predicted=632309.379268, expected=541027.500000
# predicted=641443.643815, expected=501592.500000
# predicted=626424.861159, expected=517062.000000
# predicted=631943.843207, expected=633214.000000
# predicted=675536.277064, expected=638132.000000
# predicted=677353.124274, expected=587200.000000
# predicted=658149.798705, expected=555200.000000
# predicted=645982.348844, expected=530965.000000
# predicted=636652.011575, expected=713037.500000
# predicted=705360.020293, expected=686070.000000
# predicted=695196.092627, expected=643337.500000
# predicted=679076.759220, expected=549949.307692
# predicted=643784.260695, expected=611342.625000
# predicted=666884.483373, expected=833386.000000
# predicted=750622.400645, expected=607687.450549
# predicted=665681.101994, expected=755000.000000
# predicted=721011.561072, expected=698660.500000
# predicted=699872.262165, expected=564716.500000
# predicted=649576.418904, expected=868062.500000
# predicted=763178.368317, expected=782657.125000
# predicted=731310.690001, expected=836552.375000
# predicted=751562.725178, expected=832111.000000
# predicted=750019.080697, expected=664943.000000
# predicted=687373.483173, expected=598874.000000
# predicted=662597.772358, expected=813568.500000
# predicted=742925.466905, expected=813091.500000
# predicted=742830.924590, expected=809401.500000
# predicted=741529.202338, expected=755637.500000
# predicted=721423.618274, expected=745581.500000
# predicted=717676.144115, expected=620950.000000
# predicted=670988.466967, expected=569427.000000
# predicted=651603.782834, expected=755617.318182
# predicted=721354.241089, expected=794762.015152
# predicted=736046.356687, expected=778553.666667
# predicted=730022.708009, expected=753291.500000
# predicted=720586.135538, expected=720319.500000
# predicted=708243.714398, expected=584218.500000
# predicted=657245.200483, expected=557820.000000
# predicted=647228.462811, expected=580176.000000
# predicted=655512.252546, expected=734406.500000
# predicted=713418.784378, expected=697017.500000
# predicted=699396.677538, expected=593143.000000
# predicted=660408.114454, expected=566156.000000
# predicted=650173.421751, expected=563732.375000
# predicted=649136.364501, expected=808567.500000
# predicted=741135.995520, expected=763616.357143
# predicted=724308.478384, expected=746364.500000
# predicted=717855.528367, expected=547740.500000
# predicted=643343.659167, expected=784287.000000
# predicted=731935.838543, expected=885008.500000
# predicted=769756.395594, expected=612815.000000
# predicted=667961.272501, expected=613461.000000
# predicted=668151.725345, expected=743138.000000
# predicted=716537.463821, expected=742364.000000
# predicted=716265.166014, expected=727847.000000
# predicted=710862.256056, expected=698683.000000
# predicted=699987.139692, expected=694572.000000
# predicted=698452.256187, expected=538534.000000
# predicted=640210.190989, expected=465012.500000
# predicted=612376.813525, expected=666539.000000
# predicted=687827.160554, expected=699615.500000
# predicted=700187.529482, expected=694235.500000
# predicted=698175.040139, expected=686879.000000
# predicted=695421.478831, expected=674081.000000
# predicted=690629.903925, expected=551677.000000
# predicted=644810.843039, expected=526167.000000
# predicted=635060.522933, expected=540128.000000
# predicted=640106.547459, expected=729133.500000
# predicted=711086.313507, expected=706088.500000
# predicted=702448.940110, expected=547195.000000
# predicted=642839.389372, expected=633546.000000
# predicted=675179.872397, expected=645007.750000
# predicted=679453.164174, expected=645627.500000
# predicted=679662.485919, expected=805205.000000
# predicted=739518.604700, expected=740030.000000
# predicted=715107.104082, expected=501873.500000
# predicted=625874.790777, expected=777410.000000
# predicted=728926.691553, expected=873506.000000
# predicted=764908.301868, expected=536166.000000
# predicted=639219.310387, expected=543662.000000
# predicted=641829.591793, expected=654354.000000
# predicted=683017.587430, expected=669489.000000
# predicted=688638.219971, expected=682898.000000
# predicted=693622.257342, expected=717984.000000
# predicted=706684.518160, expected=718408.000000
# predicted=706848.560064, expected=583007.000000
# predicted=656437.333141, expected=573098.000000
# predicted=652647.879983, expected=731761.000000
# predicted=711743.671263, expected=768546.000000
# predicted=725456.326628, expected=718019.000000
# predicted=706661.397066, expected=673130.900000
# predicted=689952.266462, expected=643454.600000
# predicted=678889.709373, expected=540218.000000
# predicted=640361.651445, expected=486128.000000
# predicted=619883.412503, expected=614414.000000
# predicted=667791.350318, expected=644036.000000
# predicted=678839.123581, expected=637323.500000
# predicted=676302.123033, expected=681813.500000
# predicted=692934.759188, expected=700785.000000
# predicted=700029.687833, expected=723302.000000
# predicted=708457.715442, expected=538609.500000
# predicted=639371.093934, expected=669840.500000
# predicted=688416.609266, expected=681701.931818
# predicted=692841.014669, expected=568339.500000
# predicted=650440.721637, expected=796266.500000
# predicted=735541.378620, expected=597599.000000
# predicted=661534.451022, expected=675829.000000
# predicted=690632.239487, expected=755856.000000
# predicted=720412.941573, expected=728909.500000
# predicted=710402.347030, expected=792825.000000
# predicted=734214.363649, expected=760931.000000
# predicted=722376.545348, expected=722401.500000
# predicted=708045.345895, expected=698506.000000
# predicted=699152.380717, expected=580067.000000
# predicted=655037.405269, expected=550551.500000
# predicted=643913.724640, expected=751949.750000
# predicted=718961.722898, expected=773148.250000
# predicted=726881.046498, expected=744313.500000
# predicted=716168.835169, expected=701704.500000
# predicted=700311.743758, expected=655693.000000
# predicted=683175.195843, expected=569480.500000
# predicted=651018.934722, expected=518402.500000
# predicted=631787.208985, expected=628970.000000
# predicted=673029.016888, expected=650358.500000
# predicted=680992.628429, expected=675856.000000
# predicted=690503.675389, expected=664217.500000
# predicted=686146.246617, expected=680518.692308
# predicted=692226.397336, expected=746486.000000
# predicted=716870.009917, expected=705563.000000
# predicted=701594.161541, expected=686901.000000
# predicted=694623.685110, expected=517616.000000
# predicted=631352.272115, expected=678727.000000
# predicted=691513.862144, expected=575507.318182
# predicted=652960.591888, expected=768352.750000
# predicted=724885.133764, expected=778801.500000
# predicted=728816.392759, expected=507170.000000
# predicted=627714.506202, expected=684864.000000
# predicted=693770.345060, expected=722550.000000
# predicted=707766.016933, expected=656680.500000
# predicted=683306.244281, expected=657215.125000
# predicted=683488.980471, expected=634646.500000
# predicted=675085.289563, expected=540149.000000
# predicted=639883.845919, expected=512743.000000
# predicted=629455.123665, expected=669703.500000
# predicted=687950.568720, expected=650105.900000
# predicted=680636.145141, expected=671776.225000
# predicted=688696.083081, expected=650726.750000
# predicted=680839.991195, expected=640240.125000
# predicted=676910.286823, expected=530917.000000
# predicted=636061.931506, expected=511945.500000
# predicted=628739.054590, expected=626977.000000
# predicted=671730.871050, expected=639908.000000
# predicted=676541.545045, expected=658461.375000
# predicted=683467.134583, expected=667042.625000
# predicted=686666.645257, expected=627966.000000
# predicted=672017.273883, expected=511076.000000
# predicted=628109.824192, expected=510421.000000
# predicted=627605.180130, expected=600985.000000
# predicted=661590.249220, expected=678929.000000
# predicted=690900.382552, expected=531921.500000
# predicted=635546.226909, expected=550260.500000
# predicted=642297.465998, expected=693639.500000
# predicted=696329.507890, expected=700165.500000
# predicted=698787.121145, expected=545956.750000
# predicted=640685.186856, expected=797852.964286
# predicted=735431.965569, expected=723545.500000
# predicted=707549.674984, expected=728999.500000
# predicted=709606.930539, expected=700369.000000
# predicted=698863.003273, expected=640669.000000
# predicted=676441.575932, expected=852825.000000
# predicted=756030.128256, expected=544705.400000
# predicted=640744.891991, expected=735089.000000
# predicted=711784.432729, expected=794767.090909
# predicted=734060.481000, expected=806260.409091
# predicted=738413.889627, expected=812316.875000
# predicted=740752.532849, expected=798546.825000
# predicted=735674.202344, expected=630296.800000
# predicted=672812.244054, expected=581810.454545
# predicted=654646.652309, expected=774742.545455
# predicted=726677.607324, expected=853245.500000
# predicted=756065.614492, expected=892707.000000
# predicted=771053.150922, expected=894643.714286
# predicted=772063.698618, expected=848621.285714
# predicted=754939.148439, expected=672034.500000
# predicted=688523.390625, expected=616526.000000
# predicted=667643.746223, expected=817905.500000
# predicted=743259.351036, expected=860870.500000
# predicted=759532.630844, expected=857383.000000
# predicted=758390.958413, expected=801150.000000
# predicted=737284.909438, expected=486313.000000
# predicted=618845.514638, expected=519745.000000
# predicted=631169.357969, expected=754389.500000
# predicted=719490.958872, expected=683159.500000
# predicted=692737.801448, expected=677822.750000
# predicted=690727.501248, expected=836808.660714
# predicted=750443.111149, expected=623670.000000
# predicted=670487.495046, expected=750196.000000
# predicted=717871.814288, expected=718822.000000
# predicted=706137.689100, expected=540296.000000
# predicted=639307.046016, expected=882813.500000
# predicted=767150.769589, expected=823023.000000
# predicted=744992.771438, expected=784186.000000
# predicted=730563.254499, expected=783066.000000
# predicted=730189.434145, expected=772983.500000
# predicted=726462.540424, expected=610074.000000
# predicted=665651.268048, expected=550707.111111
# predicted=643395.280128, expected=762195.388889
# predicted=722333.793041, expected=832393.000000
# predicted=748573.357440, expected=841217.857143
# predicted=751990.586530, expected=847218.309524
# predicted=754371.298462, expected=850155.833333
# predicted=755616.981665, expected=692004.318182
# predicted=696345.421439, expected=583420.681818
# predicted=655658.951509, expected=816238.500000
# predicted=742754.274817, expected=866265.000000
# predicted=761603.692324, expected=875147.000000
# predicted=765136.436815, expected=887622.500000
# predicted=770061.633476, expected=876995.571429
# predicted=766285.328674, expected=720567.120879
# predicted=707311.172964, expected=815189.000000
# predicted=742995.237560, expected=688375.000000
# predicted=695221.111128, expected=707329.000000
# predicted=702358.402255, expected=756178.000000
# predicted=720764.930218, expected=565596.000000
# predicted=649034.663337, expected=709866.000000
# predicted=703285.099490, expected=848509.125000
# predicted=755424.292587, expected=585356.500000
# predicted=656647.403167, expected=743300.000000
# predicted=715800.899711, expected=688030.000000
# predicted=695121.034003, expected=744631.000000
# predicted=716305.490960, expected=757268.000000
# predicted=721054.684881, expected=728482.125000
# predicted=710294.958292, expected=658011.000000
# predicted=683919.661795, expected=651681.000000
# predicted=681534.363462, expected=718297.000000
# predicted=706461.281074, expected=666227.000000
# predicted=686975.878345, expected=657936.875000
# predicted=683860.847361, expected=636936.625000
# predicted=675981.060173, expected=628640.000000
# predicted=672845.839157, expected=582539.666667
# predicted=655521.722726, expected=563195.833333
# predicted=648167.393939, expected=696639.000000
# predicted=698217.681310, expected=725334.000000
# predicted=708979.424900, expected=720164.000000
# predicted=707048.544621, expected=732491.000000
# predicted=711679.307061, expected=722547.250000
# predicted=707959.839394, expected=576890.977273
# predicted=653345.575804, expected=510764.272727
# predicted=628361.801484, expected=679989.000000
# predicted=691904.484974, expected=734073.500000
# predicted=712197.141644, expected=666825.500000
# predicted=686972.134347, expected=744479.500000
# predicted=716096.144348, expected=750898.000000
# predicted=718521.411489, expected=708422.722222
# predicted=702599.630855, expected=521765.000000
# predicted=632584.724270, expected=726626.500000
# predicted=709355.658163, expected=805851.500000
# predicted=739034.538017, expected=673521.000000
# predicted=689521.373862, expected=750224.500000
# predicted=718208.497859, expected=560145.000000
# predicted=647170.910813, expected=775572.000000
# predicted=727573.346429, expected=880522.000000
# predicted=766828.275531, expected=705088.000000
# predicted=701368.244070, expected=770384.000000
# predicted=725721.227886, expected=821783.500000
# predicted=744949.430043, expected=762231.000000
# predicted=722764.664696, expected=730869.625000
# predicted=711075.815672, expected=602736.303571
# predicted=663259.916458, expected=574233.571429
# predicted=652544.587605, expected=741387.500000
# predicted=714934.426500, expected=758253.000000
# predicted=721244.403915, expected=733275.000000
# predicted=711941.972884, expected=710408.875000
# predicted=703418.286299, expected=726714.125000
# predicted=709507.183221, expected=604308.000000
# predicted=663843.604455, expected=555049.000000
# predicted=645369.626353, expected=707706.000000
# predicted=702349.083214, expected=739633.000000
# predicted=714265.734469, expected=745304.500000
# predicted=716396.842051, expected=739053.000000
# predicted=714079.314810, expected=610138.500000
# predicted=665988.413158, expected=804990.500000
# predicted=738597.563092, expected=754694.000000
# predicted=719897.121615, expected=576395.777778
# predicted=653525.160567, expected=629799.000000
# predicted=673357.785628, expected=706650.272727
# predicted=701953.041308, expected=654094.000000
# predicted=682391.385883, expected=704741.000000
# predicted=701230.748895, expected=738905.000000
# predicted=713948.575829, expected=514308.000000
# predicted=630430.159217, expected=792422.000000
# predicted=733664.861618, expected=862680.000000
# predicted=759811.747012, expected=737227.500000
# predicted=713306.551649, expected=756524.000000
# predicted=720478.614718, expected=745257.000000
# predicted=716319.175672, expected=575913.500000
# predicted=653540.976296, expected=493652.000000
# predicted=622825.836290, expected=677375.000000
# predicted=691048.307435, expected=719903.000000
# predicted=706823.445845, expected=715304.000000
# predicted=705123.182341, expected=731462.000000
# predicted=711124.520769, expected=709686.000000
# predicted=703053.021505, expected=540405.142857
# predicted=640248.757148, expected=491585.857143
# predicted=621868.785395, expected=674132.000000
# predicted=689741.361300, expected=722160.000000
# predicted=707580.082405, expected=733065.500000
# predicted=711639.862032, expected=713508.500000
# predicted=704382.907498, expected=710588.500000
# predicted=703302.208503, expected=592249.000000
# predicted=659337.948237, expected=516969.500000
# predicted=631213.697939, expected=806495.500000
# predicted=738771.946849, expected=847976.000000
# predicted=754262.395786, expected=717195.000000
# predicted=705741.430188, expected=497098.428571
# predicted=624111.334947, expected=667478.250000
# predicted=687256.867424, expected=689950.782828
# predicted=695573.775663, expected=564917.000000
# predicted=649239.320745, expected=748994.750000
# predicted=717380.122272, expected=583830.000000
# predicted=656325.791909, expected=676721.000000
# predicted=690631.925248, expected=747603.000000
# predicted=716817.223396, expected=753969.000000
# predicted=719188.251449, expected=643650.000000
# predicted=678443.490954, expected=575403.000000
# predicted=653186.268670, expected=806566.000000
# predicted=738506.967854, expected=831673.000000
# predicted=747857.472929, expected=807435.000000
# predicted=738984.877874, expected=785876.000000
# predicted=731068.222870, expected=804064.000000
# predicted=737849.694128, expected=686654.500000
# predicted=694429.485449, expected=641799.000000
# predicted=677833.654565, expected=782840.000000
# predicted=729965.005798, expected=842215.750000
# predicted=751996.316317, expected=897408.750000
# predicted=772645.089033, expected=910388.500000
# predicted=777773.231823, expected=915051.000000
# predicted=779846.159425, expected=725671.500000
# predicted=709170.335938, expected=681821.222222
# predicted=692824.977828, expected=888217.777778
# predicted=769758.344142, expected=904851.500000
# predicted=776243.937687, expected=777720.000000
# predicted=728772.688341, expected=751978.500000
# predicted=719174.951972, expected=709656.000000
# predicted=703362.484848, expected=716446.071429
# predicted=705904.633673, expected=695074.125000
# predicted=697917.386347, expected=590447.044444
# predicted=658788.738551, expected=795278.500000
# predicted=735295.114961, expected=760829.625000
# predicted=722469.073443, expected=527154.000000
# predicted=635317.777468, expected=713678.000000
# predicted=704813.756093, expected=759285.000000
# predicted=721799.540594, expected=704533.500000
# predicted=701430.500482, expected=888134.500000
# predicted=769792.756337, expected=924846.500000
# predicted=783803.840579, expected=876030.500000
# predicted=765790.113634, expected=899276.000000
# predicted=774750.792767, expected=909511.000000
# predicted=778896.366664, expected=753419.000000
# predicted=720143.007239, expected=728141.000000
# predicted=710642.256145, expected=938997.000000
# predicted=790102.384050, expected=965264.500000
# predicted=800547.364271, expected=896322.000000
# predicted=774737.160896, expected=784465.000000
# predicted=732330.323548, expected=664101.500000
# predicted=686654.171837, expected=537114.500000
# predicted=638412.708954, expected=524001.500000
# predicted=633245.046882, expected=594962.000000
# predicted=660168.456184, expected=567324.000000
# predicted=649557.251786, expected=559071.000000
# predicted=646300.366585, expected=515478.500000
# predicted=629471.985454, expected=480039.000000
# Test RMSE: 94581.189

# %%
scaler = MinMaxScaler(feature_range = (-1,1))

norm_series = pd.DataFrame(series)
norm_series = scaler.fit_transform(norm_series)

# %%
train_norm, test_norm = norm_series[0:len(norm_series)-730], norm_series[len(norm_series)-730:]
model = ARIMA(norm_series, order=(1,0,0))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2192
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                -915.075
# Date:                Thu, 23 Feb 2023   AIC                           1836.150
# Time:                        09:12:35   BIC                           1853.228
# Sample:                             0   HQIC                          1842.392
#                                - 2192
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0741      0.013     -5.807      0.000      -0.099      -0.049
# ar.L1          0.3835      0.019     20.047      0.000       0.346       0.421
# sigma2         0.1349      0.005     26.932      0.000       0.125       0.145
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.82   Jarque-Bera (JB):                27.08
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                            -0.01
# Prob(H) (two-sided):                  0.78   Kurtosis:                         2.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# train autoregression
history = [x for x in train_norm]
predictions = list()
for t in range(len(test_norm)):
    model = ARIMA(history, order=(1,0,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_norm[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test_norm, predictions))

print('Test RMSE: %.3f' % rmse)
# plot
pyplot.plot(test_norm)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=-0.300442, expected=-0.382844
# predicted=-0.164583, expected=-0.838592
# predicted=-0.325133, expected=-0.371709
# predicted=-0.161562, expected=-0.623211
# predicted=-0.250457, expected=-0.439791
# predicted=-0.186329, expected=0.361635
# predicted=0.095624, expected=0.153237
# predicted=0.022559, expected=0.491870
# predicted=0.141959, expected=-0.063859
# predicted=-0.053458, expected=-0.897366
# predicted=-0.346575, expected=0.252708
# predicted=0.056815, expected=0.231069
# predicted=0.049450, expected=0.344292
# predicted=0.089303, expected=0.343909
# predicted=0.089511, expected=0.283919
# predicted=0.068769, expected=0.258356
# predicted=0.060030, expected=-0.303161
# predicted=-0.136835, expected=-0.607618
# predicted=-0.243977, expected=0.313429
# predicted=0.078666, expected=0.488787
# predicted=0.140498, expected=0.497427
# predicted=0.144210, expected=0.623737
# predicted=0.189565, expected=0.508766
# predicted=0.149861, expected=-0.252148
# predicted=-0.118499, expected=-0.586169
# predicted=-0.236490, expected=0.246422
# predicted=0.056613, expected=0.358799
# predicted=0.096405, expected=0.339668
# predicted=0.090011, expected=0.251335
# predicted=0.059129, expected=0.118127
# predicted=0.012293, expected=-0.426642
# predicted=-0.179676, expected=-0.728366
# predicted=-0.286793, expected=-0.015873
# predicted=-0.035369, expected=-0.586113
# predicted=-0.236346, expected=-0.565686
# predicted=-0.229777, expected=-0.436206
# predicted=-0.184445, expected=0.440120
# predicted=0.124823, expected=-0.246505
# predicted=-0.116944, expected=0.455809
# predicted=0.129845, expected=-0.116020
# predicted=-0.070828, expected=-0.334447
# predicted=-0.147516, expected=0.574500
# predicted=0.170783, expected=0.123355
# predicted=0.013111, expected=0.080082
# predicted=-0.001951, expected=-0.521515
# predicted=-0.212298, expected=-0.872230
# predicted=-0.336247, expected=-0.062703
# predicted=-0.052428, expected=0.056821
# predicted=-0.010595, expected=0.114519
# predicted=0.009655, expected=0.088217
# predicted=0.000523, expected=0.021812
# predicted=-0.022670, expected=-0.488142
# predicted=-0.201151, expected=-0.808664
# predicted=-0.314404, expected=-0.075248
# predicted=-0.057151, expected=0.014352
# predicted=-0.025767, expected=0.064873
# predicted=-0.008036, expected=0.015505
# predicted=-0.025287, expected=-0.031142
# predicted=-0.041606, expected=-0.632677
# predicted=-0.252370, expected=-0.407574
# predicted=-0.173885, expected=0.035201
# predicted=-0.018752, expected=0.021104
# predicted=-0.023656, expected=-0.649116
# predicted=-0.258407, expected=-0.611047
# predicted=-0.245833, expected=-0.073946
# predicted=-0.057442, expected=0.359331
# predicted=0.094509, expected=0.362752
# predicted=0.096071, expected=0.305360
# predicted=0.076217, expected=-0.493914
# predicted=-0.204236, expected=-0.211197
# predicted=-0.105279, expected=0.426046
# predicted=0.117968, expected=-0.533531
# predicted=-0.217386, expected=-0.864518
# predicted=-0.334201, expected=-0.828463
# predicted=-0.323230, expected=-0.526631
# predicted=-0.217613, expected=-0.580635
# predicted=-0.237246, expected=-0.600865
# predicted=-0.245063, expected=-0.627834
# predicted=-0.255355, expected=-0.690642
# predicted=-0.278569, expected=-1.000000
# predicted=-0.390835, expected=-0.998111
# predicted=-0.392806, expected=-0.450280
# predicted=-0.195820, expected=-0.636578
# predicted=-0.263600, expected=-0.589933
# predicted=-0.247405, expected=-0.585498
# predicted=-0.246416, expected=-0.688401
# predicted=-0.284594, expected=-0.851425
# predicted=-0.345351, expected=-0.813169
# predicted=-0.332855, expected=-0.683362
# predicted=-0.286222, expected=-0.574661
# predicted=-0.246863, expected=-0.604205
# predicted=-0.258380, expected=0.122303
# predicted=0.009654, expected=-0.092717
# predicted=-0.069527, expected=-0.563535
# predicted=-0.243090, expected=-0.330539
# predicted=-0.157462, expected=-0.096131
# predicted=-0.071125, expected=-0.359923
# predicted=-0.168419, expected=0.310232
# predicted=0.078370, expected=0.259092
# predicted=0.059773, expected=-0.814254
# predicted=-0.334717, expected=-0.213613
# predicted=-0.114334, expected=0.260918
# predicted=0.059659, expected=-0.759370
# predicted=-0.313635, expected=-0.538649
# predicted=-0.233515, expected=-0.468543
# predicted=-0.208216, expected=-0.535583
# predicted=-0.233229, expected=-0.552948
# predicted=-0.240104, expected=-0.662917
# predicted=-0.281270, expected=-0.738327
# predicted=-0.310073, expected=-0.407871
# predicted=-0.188215, expected=-0.420108
# predicted=-0.193001, expected=-0.448845
# predicted=-0.203935, expected=-0.466230
# predicted=-0.210703, expected=-0.452513
# predicted=-0.205927, expected=-0.538308
# predicted=-0.238215, expected=-0.616451
# predicted=-0.267885, expected=-0.412971
# predicted=-0.192351, expected=-0.391065
# predicted=-0.184407, expected=-0.315731
# predicted=-0.156448, expected=-0.353684
# predicted=-0.170788, expected=-0.643881
# predicted=-0.279705, expected=0.188267
# predicted=0.031327, expected=-0.062999
# predicted=-0.062369, expected=-0.655317
# predicted=-0.283423, expected=-0.406411
# predicted=-0.190865, expected=-0.136417
# predicted=-0.090155, expected=-0.518540
# predicted=-0.232932, expected=0.084077
# predicted=-0.008093, expected=-0.415081
# predicted=-0.194123, expected=-0.262362
# predicted=-0.137357, expected=-0.341425
# predicted=-0.166958, expected=-0.300857
# predicted=-0.151970, expected=-0.198100
# predicted=-0.113727, expected=-0.255687
# predicted=-0.135285, expected=-0.214963
# predicted=-0.120169, expected=-0.481975
# predicted=-0.219999, expected=-0.642413
# predicted=-0.280495, expected=-0.251839
# predicted=-0.134545, expected=-0.127150
# predicted=-0.087964, expected=-0.124182
# predicted=-0.086878, expected=-0.161600
# predicted=-0.100904, expected=-0.316101
# predicted=-0.158774, expected=-0.513236
# predicted=-0.232811, expected=-0.582636
# predicted=-0.259304, expected=-0.183381
# predicted=-0.109672, expected=-0.031122
# predicted=-0.052610, expected=-0.040793
# predicted=-0.056224, expected=-0.160332
# predicted=-0.101046, expected=-0.301849
# predicted=-0.154174, expected=-0.509256
# predicted=-0.232213, expected=-0.587060
# predicted=-0.261918, expected=-0.452019
# predicted=-0.211486, expected=0.195923
# predicted=0.032118, expected=-0.074998
# predicted=-0.069599, expected=-0.643299
# predicted=-0.283136, expected=-0.415355
# predicted=-0.197815, expected=-0.515004
# predicted=-0.235615, expected=0.150560
# predicted=0.014630, expected=0.139297
# predicted=0.010503, expected=-0.524762
# predicted=-0.238839, expected=-0.142742
# predicted=-0.095566, expected=-0.247228
# predicted=-0.134816, expected=-0.447662
# predicted=-0.210200, expected=-0.405726
# predicted=-0.194695, expected=-0.417123
# predicted=-0.199211, expected=0.113663
# predicted=0.000230, expected=0.304315
# predicted=0.072011, expected=0.442607
# predicted=0.124414, expected=0.376695
# predicted=0.100017, expected=0.119023
# predicted=0.003058, expected=-0.385815
# predicted=-0.187104, expected=-0.447344
# predicted=-0.210527, expected=0.130042
# predicted=0.006926, expected=0.332026
# predicted=0.083155, expected=0.366376
# predicted=0.096439, expected=0.273917
# predicted=0.061827, expected=0.134147
# predicted=0.009209, expected=-0.323617
# predicted=-0.163505, expected=-0.510299
# predicted=-0.234202, expected=0.254393
# predicted=0.054185, expected=0.317074
# predicted=0.078054, expected=0.022754
# predicted=-0.032821, expected=0.169017
# predicted=0.022384, expected=-0.654011
# predicted=-0.287589, expected=-0.575076
# predicted=-0.258420, expected=-0.302322
# predicted=-0.155746, expected=-0.505502
# predicted=-0.232634, expected=0.390074
# predicted=0.104903, expected=0.161565
# predicted=0.019050, expected=0.242827
# predicted=0.049805, expected=-0.027374
# predicted=-0.051908, expected=-0.611796
# predicted=-0.272038, expected=0.167426
# predicted=0.021060, expected=0.122298
# predicted=0.004208, expected=0.219724
# predicted=0.040941, expected=0.382446
# predicted=0.102402, expected=0.425913
# predicted=0.119204, expected=0.312069
# predicted=0.076614, expected=-0.273393
# predicted=-0.144033, expected=-0.593681
# predicted=-0.264983, expected=0.091900
# predicted=-0.006727, expected=0.352505
# predicted=0.091523, expected=0.375912
# predicted=0.100696, expected=0.405786
# predicted=0.112368, expected=0.252610
# predicted=0.054782, expected=-0.247529
# predicted=-0.134016, expected=-0.570535
# predicted=-0.256172, expected=0.220351
# predicted=0.042175, expected=0.359544
# predicted=0.094888, expected=0.415004
# predicted=0.116215, expected=0.520759
# predicted=0.156773, expected=0.613033
# predicted=0.192599, expected=0.173780
# predicted=0.026144, expected=-0.469815
# predicted=-0.217794, expected=-0.764702
# predicted=-0.330296, expected=-0.608251
# predicted=-0.271529, expected=-0.395368
# predicted=-0.190796, expected=0.035908
# predicted=-0.026704, expected=0.412734
# predicted=0.116813, expected=-0.224765
# predicted=-0.125616, expected=0.298218
# predicted=0.073016, expected=-0.122347
# predicted=-0.086582, expected=-0.896360
# predicted=-0.380546, expected=0.158557
# predicted=0.019378, expected=0.139221
# predicted=0.012170, expected=0.157082
# predicted=0.019024, expected=-0.265716
# predicted=-0.140780, expected=-0.452318
# predicted=-0.211488, expected=0.080230
# predicted=-0.010243, expected=0.115736
# predicted=0.003238, expected=0.043469
# predicted=-0.024003, expected=0.062516
# predicted=-0.016760, expected=-0.064235
# predicted=-0.064622, expected=-0.313704
# predicted=-0.158910, expected=-0.503682
# predicted=-0.230946, expected=0.242630
# predicted=0.050967, expected=0.297345
# predicted=0.071837, expected=0.365863
# predicted=0.098026, expected=0.589113
# predicted=0.183127, expected=0.364570
# predicted=0.098460, expected=-0.136581
# predicted=-0.091498, expected=-0.327247
# predicted=-0.163811, expected=0.326615
# predicted=0.083784, expected=0.239371
# predicted=0.050962, expected=-0.747156
# predicted=-0.322048, expected=-0.212999
# predicted=-0.120376, expected=-0.675600
# predicted=-0.295326, expected=-0.530832
# predicted=-0.241081, expected=0.199081
# predicted=0.034825, expected=0.523623
# predicted=0.157796, expected=-0.411810
# predicted=-0.195358, expected=0.324768
# predicted=0.081929, expected=-0.155590
# predicted=-0.098660, expected=-0.232051
# predicted=-0.127448, expected=0.626336
# predicted=0.194929, expected=-0.435879
# predicted=-0.203123, expected=0.291290
# predicted=0.068409, expected=0.563899
# predicted=0.170697, expected=0.456053
# predicted=0.130944, expected=0.384874
# predicted=0.104690, expected=0.387830
# predicted=0.106171, expected=-0.237614
# predicted=-0.128425, expected=-0.521192
# predicted=-0.234929, expected=0.294515
# predicted=0.070633, expected=0.329389
# predicted=0.083948, expected=0.356899
# predicted=0.094561, expected=0.229943
# predicted=0.047161, expected=0.223831
# predicted=0.045027, expected=-0.422401
# predicted=-0.197305, expected=-0.700910
# predicted=-0.302284, expected=0.049073
# predicted=-0.020910, expected=0.238667
# predicted=0.050218, expected=0.072132
# predicted=-0.012102, expected=0.249640
# predicted=0.054536, expected=0.111808
# predicted=0.002967, expected=-0.191479
# predicted=-0.110717, expected=-0.633570
# predicted=-0.276680, expected=-0.683781
# predicted=-0.296255, expected=0.332291
# predicted=0.085081, expected=0.375360
# predicted=0.101542, expected=-0.002882
# predicted=-0.040178, expected=0.327278
# predicted=0.083652, expected=-0.568168
# predicted=-0.251515, expected=-0.182689
# predicted=-0.107490, expected=0.547442
# predicted=0.165309, expected=0.030058
# predicted=-0.027816, expected=-0.106956
# predicted=-0.078935, expected=0.074040
# predicted=-0.011386, expected=-0.010930
# predicted=-0.043055, expected=-0.505101
# predicted=-0.227468, expected=-0.741063
# predicted=-0.316250, expected=-0.133193
# predicted=-0.089098, expected=-0.143857
# predicted=-0.093108, expected=-0.196100
# predicted=-0.112659, expected=-0.069749
# predicted=-0.065498, expected=-0.149176
# predicted=-0.095175, expected=-0.662244
# predicted=-0.286998, expected=-0.717919
# predicted=-0.308634, expected=-0.228801
# predicted=-0.125554, expected=-0.110283
# predicted=-0.081223, expected=-0.126938
# predicted=-0.087478, expected=-0.104420
# predicted=-0.079067, expected=-0.197040
# predicted=-0.113773, expected=-0.725994
# predicted=-0.312135, expected=-0.377329
# predicted=-0.181723, expected=0.145723
# predicted=0.014233, expected=-0.231392
# predicted=-0.126939, expected=-0.625782
# predicted=-0.274844, expected=-0.379028
# predicted=-0.182639, expected=-0.006448
# predicted=-0.043061, expected=-0.249944
# predicted=-0.134284, expected=0.156031
# predicted=0.017731, expected=0.253247
# predicted=0.054278, expected=-0.726889
# predicted=-0.312279, expected=-0.143236
# predicted=-0.094305, expected=0.220505
# predicted=0.041466, expected=-0.136000
# predicted=-0.091510, expected=-0.599336
# predicted=-0.264493, expected=-0.825285
# predicted=-0.349838, expected=-0.145759
# predicted=-0.095685, expected=-0.072611
# predicted=-0.068371, expected=-0.062966
# predicted=-0.064768, expected=-0.087401
# predicted=-0.073900, expected=-0.021913
# predicted=-0.049430, expected=-0.430124
# predicted=-0.201972, expected=-0.633689
# predicted=-0.278496, expected=-0.064721
# predicted=-0.065741, expected=-0.015056
# predicted=-0.047174, expected=-0.043141
# predicted=-0.057655, expected=0.022019
# predicted=-0.033287, expected=0.052226
# predicted=-0.021960, expected=-0.393731
# predicted=-0.188601, expected=-0.585558
# predicted=-0.260647, expected=0.152086
# predicted=0.015022, expected=-0.535168
# predicted=-0.241336, expected=0.122815
# predicted=0.003808, expected=-0.404695
# predicted=-0.192468, expected=-0.729450
# predicted=-0.313860, expected=-0.252040
# predicted=-0.136106, expected=-0.181269
# predicted=-0.109804, expected=-0.486053
# predicted=-0.223482, expected=0.146266
# predicted=0.011978, expected=-0.252744
# predicted=-0.136438, expected=-0.039958
# predicted=-0.057339, expected=-0.074521
# predicted=-0.070186, expected=-0.326457
# predicted=-0.163904, expected=-0.442515
# predicted=-0.207261, expected=0.128500
# predicted=0.005074, expected=0.200187
# predicted=0.031831, expected=0.235830
# predicted=0.045239, expected=0.212730
# predicted=0.036798, expected=0.172054
# predicted=0.021784, expected=-0.513448
# predicted=-0.233234, expected=-0.785001
# predicted=-0.335027, expected=-0.157189
# predicted=-0.101153, expected=-0.102254
# predicted=-0.080726, expected=-0.259404
# predicted=-0.139265, expected=-0.781246
# predicted=-0.333988, expected=-0.684829
# predicted=-0.298829, expected=-0.836535
# predicted=-0.356638, expected=-0.777024
# predicted=-0.335395, expected=-0.330188
# predicted=-0.167602, expected=-0.311269
# predicted=-0.160609, expected=-0.507204
# predicted=-0.234524, expected=-0.630308
# predicted=-0.281358, expected=-0.723540
# predicted=-0.317272, expected=-0.023108
# predicted=-0.052807, expected=-0.126852
# predicted=-0.091929, expected=-0.291243
# predicted=-0.153974, expected=-0.650507
# predicted=-0.289818, expected=-0.414327
# predicted=-0.200902, expected=0.439872
# predicted=0.121413, expected=-0.428389
# predicted=-0.205533, expected=0.138322
# predicted=0.007438, expected=-0.078416
# predicted=-0.073928, expected=-0.593698
# predicted=-0.267521, expected=0.573273
# predicted=0.169743, expected=0.244719
# predicted=0.047081, expected=0.452053
# predicted=0.125033, expected=0.434967
# predicted=0.119091, expected=-0.208127
# predicted=-0.122037, expected=-0.462294
# predicted=-0.217400, expected=0.363635
# predicted=0.091788, expected=0.361799
# predicted=0.091423, expected=0.347604
# predicted=0.086413, expected=0.140774
# predicted=0.009024, expected=0.102089
# predicted=-0.005400, expected=-0.377368
# predicted=-0.185103, expected=-0.575576
# predicted=-0.259716, expected=0.140697
# predicted=0.008758, expected=0.291286
# predicted=0.065309, expected=0.228933
# predicted=0.042123, expected=0.131749
# predicted=0.005801, expected=0.004906
# predicted=-0.041705, expected=-0.518674
# predicted=-0.238001, expected=-0.620229
# predicted=-0.276557, expected=-0.534225
# predicted=-0.244671, expected=0.059099
# predicted=-0.021786, expected=-0.084737
# predicted=-0.075757, expected=-0.484341
# predicted=-0.225826, expected=-0.588160
# predicted=-0.265220, expected=-0.597484
# predicted=-0.269212, expected=0.344396
# predicted=0.084900, expected=0.171469
# predicted=0.020130, expected=0.105101
# predicted=-0.004708, expected=-0.659004
# predicted=-0.291507, expected=0.250989
# predicted=0.049489, expected=0.638464
# predicted=0.195062, expected=-0.408663
# predicted=-0.196752, expected=-0.406178
# predicted=-0.196018, expected=0.092689
# predicted=-0.009780, expected=0.089711
# predicted=-0.010828, expected=0.033864
# predicted=-0.031623, expected=-0.078329
# predicted=-0.073482, expected=-0.094144
# predicted=-0.079390, expected=-0.694422
# predicted=-0.303566, expected=-0.977258
# predicted=-0.410699, expected=-0.201987
# predicted=-0.120286, expected=-0.074742
# predicted=-0.072710, expected=-0.095439
# predicted=-0.080456, expected=-0.123739
# predicted=-0.091054, expected=-0.172973
# predicted=-0.109497, expected=-0.643861
# predicted=-0.285856, expected=-0.741997
# predicted=-0.323386, expected=-0.688290
# predicted=-0.303963, expected=0.038814
# predicted=-0.030760, expected=-0.049840
# predicted=-0.064005, expected=-0.661103
# predicted=-0.293444, expected=-0.328911
# predicted=-0.168964, expected=-0.284818
# predicted=-0.152515, expected=-0.282434
# predicted=-0.151710, expected=0.331460
# predicted=0.078678, expected=0.080732
# predicted=-0.015283, expected=-0.835454
# predicted=-0.358740, expected=0.224533
# predicted=0.037910, expected=0.594214
# predicted=0.176404, expected=-0.703531
# predicted=-0.307374, expected=-0.674694
# predicted=-0.297327, expected=-0.248863
# predicted=-0.138793, expected=-0.190639
# predicted=-0.117159, expected=-0.139054
# predicted=-0.097976, expected=-0.004079
# predicted=-0.047699, expected=-0.002447
# predicted=-0.047067, expected=-0.523334
# predicted=-0.241100, expected=-0.561454
# predicted=-0.255686, expected=0.048922
# predicted=-0.028226, expected=0.190433
# predicted=0.024554, expected=-0.003944
# predicted=-0.047787, expected=-0.176628
# predicted=-0.112100, expected=-0.290793
# predicted=-0.154680, expected=-0.687943
# predicted=-0.302975, expected=-0.896027
# predicted=-0.381796, expected=-0.402512
# predicted=-0.197398, expected=-0.288556
# predicted=-0.154874, expected=-0.314379
# predicted=-0.164639, expected=-0.143226
# predicted=-0.100620, expected=-0.070243
# predicted=-0.073312, expected=0.016380
# predicted=-0.040872, expected=-0.694131
# predicted=-0.306786, expected=-0.189286
# predicted=-0.118010, expected=-0.143655
# predicted=-0.100980, expected=-0.579760
# predicted=-0.264178, expected=0.297074
# predicted=0.063374, expected=-0.467199
# predicted=-0.221478, expected=-0.166249
# predicted=-0.109480, expected=0.141615
# predicted=0.005145, expected=0.037952
# predicted=-0.033386, expected=0.283834
# predicted=0.058266, expected=0.161138
# predicted=0.012702, expected=0.012916
# predicted=-0.042458, expected=-0.079010
# predicted=-0.076686, expected=-0.534644
# predicted=-0.246484, expected=-0.648190
# predicted=-0.289299, expected=0.126588
# predicted=-0.000441, expected=0.208138
# predicted=0.030041, expected=0.097211
# predicted=-0.011190, expected=-0.066706
# predicted=-0.072223, expected=-0.243712
# predicted=-0.138181, expected=-0.575371
# predicted=-0.261950, expected=-0.771867
# predicted=-0.335973, expected=-0.346515
# predicted=-0.177233, expected=-0.264233
# predicted=-0.146582, expected=-0.166145
# predicted=-0.109974, expected=-0.210918
# predicted=-0.126745, expected=-0.148207
# predicted=-0.103343, expected=0.105569
# predicted=-0.008491, expected=-0.051862
# predicted=-0.067286, expected=-0.123655
# predicted=-0.094115, expected=-0.774893
# predicted=-0.337645, expected=-0.155100
# predicted=-0.106084, expected=-0.552186
# predicted=-0.254474, expected=0.189690
# predicted=0.022360, expected=0.229886
# predicted=0.037491, expected=-0.815079
# predicted=-0.351645, expected=-0.131491
# predicted=-0.097398, expected=0.013487
# predicted=-0.043529, expected=-0.239913
# predicted=-0.137674, expected=-0.237856
# predicted=-0.136970, expected=-0.324677
# predicted=-0.169315, expected=-0.688209
# predicted=-0.304804, expected=-0.793640
# predicted=-0.344944, expected=-0.189813
# predicted=-0.119797, expected=-0.265205
# predicted=-0.147950, expected=-0.181840
# predicted=-0.116927, expected=-0.262817
# predicted=-0.147165, expected=-0.303159
# predicted=-0.162290, expected=-0.723724
# predicted=-0.319513, expected=-0.796708
# predicted=-0.347699, expected=-0.354182
# predicted=-0.182225, expected=-0.304436
# predicted=-0.163709, expected=-0.233062
# predicted=-0.137053, expected=-0.200050
# predicted=-0.124738, expected=-0.350377
# predicted=-0.181122, expected=-0.800052
# predicted=-0.350120, expected=-0.802572
# predicted=-0.352062, expected=-0.454173
# predicted=-0.221255, expected=-0.154323
# predicted=-0.108442, expected=-0.719860
# predicted=-0.321497, expected=-0.649310
# predicted=-0.295511, expected=-0.097732
# predicted=-0.087545, expected=-0.072626
# predicted=-0.078086, expected=-0.665866
# predicted=-0.301716, expected=0.303177
# predicted=0.062958, expected=0.017317
# predicted=-0.044359, expected=0.038298
# predicted=-0.036441, expected=-0.071843
# predicted=-0.077793, expected=-0.301509
# predicted=-0.164091, expected=0.514654
# predicted=0.142239, expected=-0.670680
# predicted=-0.301484, expected=0.061724
# predicted=-0.028058, expected=0.291306
# predicted=0.057681, expected=0.335520
# predicted=0.074436, expected=0.358820
# predicted=0.083438, expected=0.305846
# predicted=0.063891, expected=-0.341411
# predicted=-0.178059, expected=-0.527937
# predicted=-0.247977, expected=0.214271
# predicted=0.029264, expected=0.516272
# predicted=0.142376, expected=0.668080
# predicted=0.200061, expected=0.675530
# predicted=0.203950, expected=0.498482
# predicted=0.138039, expected=-0.180846
# predicted=-0.117589, expected=-0.394387
# predicted=-0.197953, expected=0.380319
# predicted=0.093085, expected=0.545605
# predicted=0.155719, expected=0.532189
# predicted=0.151324, expected=0.315861
# predicted=0.070088, expected=-0.895316
# predicted=-0.385774, expected=-0.766703
# predicted=-0.338340, expected=0.135973
# predicted=0.001602, expected=-0.138048
# predicted=-0.101368, expected=-0.158579
# predicted=-0.109105, expected=0.453039
# predicted=0.120734, expected=-0.366904
# predicted=-0.187006, expected=0.119841
# predicted=-0.004629, expected=-0.000855
# predicted=-0.049792, expected=-0.687643
# predicted=-0.307017, expected=0.630020
# predicted=0.185042, expected=0.400006
# predicted=0.099758, expected=0.250600
# predicted=0.044219, expected=0.246292
# predicted=0.042780, expected=0.207504
# predicted=0.028436, expected=-0.419208
# predicted=-0.205619, expected=-0.647592
# predicted=-0.291281, expected=0.166002
# predicted=0.012545, expected=0.436052
# predicted=0.113539, expected=0.470001
# predicted=0.126691, expected=0.493085
# predicted=0.135854, expected=0.504386
# predicted=0.140648, expected=-0.104022
# predicted=-0.087482, expected=-0.521743
# predicted=-0.244079, expected=0.373906
# predicted=0.091141, expected=0.566358
# predicted=0.163690, expected=0.600527
# predicted=0.177287, expected=0.648520
# predicted=0.196242, expected=0.607638
# predicted=0.181707, expected=0.005859
# predicted=-0.045277, expected=0.369869
# predicted=0.092066, expected=-0.117984
# predicted=-0.091810, expected=-0.045068
# predicted=-0.064340, expected=0.142854
# predicted=0.006504, expected=-0.590314
# predicted=-0.269576, expected=-0.035308
# predicted=-0.060772, expected=0.498051
# predicted=0.139905, expected=-0.514296
# predicted=-0.240274, expected=0.093312
# predicted=-0.012600, expected=-0.119311
# predicted=-0.092194, expected=0.098432
# predicted=-0.010658, expected=0.147047
# predicted=0.007621, expected=0.036308
# predicted=-0.033792, expected=-0.234794
# predicted=-0.135306, expected=-0.259146
# predicted=-0.144487, expected=-0.002874
# predicted=-0.048546, expected=-0.203187
# predicted=-0.123543, expected=-0.235079
# predicted=-0.135532, expected=-0.315867
# predicted=-0.165860, expected=-0.347784
# predicted=-0.177927, expected=-0.525132
# predicted=-0.244605, expected=-0.599548
# predicted=-0.272911, expected=-0.086193
# predicted=-0.080274, expected=0.024197
# predicted=-0.038854, expected=0.004308
# predicted=-0.046285, expected=0.051730
# predicted=-0.028462, expected=0.013476
# predicted=-0.042778, expected=-0.546863
# predicted=-0.252980, expected=-0.801252
# predicted=-0.349139, expected=-0.150245
# predicted=-0.104572, expected=0.057818
# predicted=-0.026469, expected=-0.200885
# predicted=-0.123556, expected=0.097850
# predicted=-0.011462, expected=0.122541
# predicted=-0.002128, expected=-0.040861
# predicted=-0.063408, expected=-0.758932
# predicted=-0.332884, expected=0.029169
# predicted=-0.037404, expected=0.333947
# predicted=0.076825, expected=-0.175127
# predicted=-0.113743, expected=0.119950
# predicted=-0.003331, expected=-0.611284
# predicted=-0.276743, expected=0.217462
# predicted=0.032713, expected=0.621204
# predicted=0.183799, expected=-0.053689
# predicted=-0.068146, expected=0.197504
# predicted=0.025584, expected=0.395238
# predicted=0.099591, expected=0.166139
# predicted=0.014205, expected=0.045492
# predicted=-0.030783, expected=-0.447436
# predicted=-0.214818, expected=-0.557086
# predicted=-0.256060, expected=0.085955
# predicted=-0.015932, expected=0.150836
# predicted=0.008354, expected=0.054746
# predicted=-0.027449, expected=-0.033220
# predicted=-0.060255, expected=0.029506
# predicted=-0.036820, expected=-0.441389
# predicted=-0.212571, expected=-0.630889
# predicted=-0.283674, expected=-0.043618
# predicted=-0.064370, expected=0.079205
# predicted=-0.018505, expected=0.101023
# predicted=-0.010303, expected=0.076974
# predicted=-0.019223, expected=-0.418960
# predicted=-0.204315, expected=0.330635
# predicted=0.075145, expected=0.137145
# predicted=0.003169, expected=-0.548768
# predicted=-0.252284, expected=-0.343326
# predicted=-0.175951, expected=-0.047679
# predicted=-0.065893, expected=-0.249863
# predicted=-0.141182, expected=-0.055024
# predicted=-0.068673, expected=0.076404
# predicted=-0.019725, expected=-0.787619
# predicted=-0.341171, expected=0.282284
# predicted=0.056161, expected=0.552566
# predicted=0.156795, expected=0.069951
# predicted=-0.022195, expected=0.144185
# predicted=0.005409, expected=0.100841
# predicted=-0.010600, expected=-0.550623
# predicted=-0.252221, expected=-0.867082
# predicted=-0.370438, expected=-0.160301
# predicted=-0.107862, expected=0.003304
# predicted=-0.047146, expected=-0.014388
# predicted=-0.053690, expected=0.047771
# predicted=-0.030593, expected=-0.036001
# predicted=-0.061658, expected=-0.687223
# predicted=-0.303379, expected=-0.875031
# predicted=-0.374121, expected=-0.172777
# predicted=-0.112891, expected=0.011987
# predicted=-0.044234, expected=0.053940
# predicted=-0.028609, expected=-0.021296
# predicted=-0.056539, expected=-0.032529
# predicted=-0.060698, expected=-0.487780
# predicted=-0.229908, expected=-0.777380
# predicted=-0.338153, expected=0.336425
# predicted=0.075818, expected=0.496000
# predicted=0.135438, expected=-0.007114
# predicted=-0.051310, expected=-0.853824
# predicted=-0.365487, expected=-0.198374
# predicted=-0.122452, expected=-0.111922
# predicted=-0.090442, expected=-0.592926
# predicted=-0.268774, expected=0.115220
# predicted=-0.006514, expected=-0.520168
# predicted=-0.241499, expected=-0.162817
# predicted=-0.109461, expected=0.109866
# predicted=-0.008680, expected=0.134356
# predicted=0.000445, expected=-0.290041
# predicted=-0.156372, expected=-0.552587
# predicted=-0.253581, expected=0.336696
# predicted=0.074800, expected=0.433282
# predicted=0.110788, expected=0.340039
# predicted=0.076639, expected=0.257102
# predicted=0.046169, expected=0.327071
# predicted=0.072269, expected=-0.124603
# predicted=-0.094845, expected=-0.297162
# predicted=-0.158719, expected=0.245422
# predicted=0.041923, expected=0.473840
# predicted=0.126717, expected=0.686167
# predicted=0.206189, expected=0.736101
# predicted=0.225926, expected=0.754037
# predicted=0.233908, expected=0.025495
# predicted=-0.038113, expected=-0.143197
# predicted=-0.101022, expected=0.650810
# predicted=0.195077, expected=0.714800
# predicted=0.220038, expected=0.225726
# predicted=0.037331, expected=0.126698
# predicted=0.000391, expected=-0.036116
# predicted=-0.060466, expected=-0.009995
# predicted=-0.050682, expected=-0.092213
# predicted=-0.081423, expected=-0.494712
# predicted=-0.232020, expected=0.293273
# predicted=0.062435, expected=0.160748
# predicted=0.013070, expected=-0.738200
# predicted=-0.322354, expected=-0.020644
# predicted=-0.054879, expected=0.154806
# predicted=0.010494, expected=-0.055823
# predicted=-0.067901, expected=0.650489
# predicted=0.195209, expected=0.791720
# predicted=0.249123, expected=0.603925
# predicted=0.179803, expected=0.693351
# predicted=0.214289, expected=0.732725
# predicted=0.230266, expected=0.132240
# predicted=0.004116, expected=0.034995
# predicted=-0.032450, expected=0.846157
# predicted=0.273349, expected=0.947208
# predicted=0.313572, expected=0.681987
# predicted=0.214234, expected=0.251674
# predicted=0.051020, expected=-0.211364
# predicted=-0.124775, expected=-0.699882
# predicted=-0.310445, expected=-0.750328
# predicted=-0.330334, expected=-0.477343
# predicted=-0.226712, expected=-0.583667
# predicted=-0.267552, expected=-0.615416
# predicted=-0.280087, expected=-0.783116
# predicted=-0.344855, expected=-0.919452
# Test RMSE: 0.364

# %%
predictions
# Out:
# [-0.3004416097451308,
#  -0.1645833936498363,
#  -0.3251332820102181,
#  -0.1615618659300666,
#  -0.2504565123199667,
#  -0.18632861165719067,
#  0.09562425979970623,
#  0.022559459892769633,
#  0.14195890892194135,
#  -0.05345784198019405,
#  -0.3465754877194918,
#  0.056814619371854475,
#  0.049449503868410606,
#  0.08930273170043951,
#  0.08951124486612635,
#  0.06876884868643288,
#  0.06003029122074867,
#  -0.13683451552113512,
#  -0.24397651555762565,
#  0.0786662225826332,
#  0.1404975804212724,
#  0.14421027555898014,
#  0.1895653682750969,
#  0.14986111769834226,
#  -0.11849927231574768,
#  -0.2364903573955907,
#  0.056613496072653424,
#  0.09640530368363105,
#  0.09001061542474133,
#  0.059128898940401214,
#  0.012293092992645187,
#  -0.1796760776615155,
#  -0.28679295791061904,
#  -0.0353689850739948,
#  -0.23634569535631478,
#  -0.22977669622107177,
#  -0.1844447328590567,
#  0.12482295986112239,
#  -0.11694376437115908,
#  0.12984521967703613,
#  -0.0708280893361496,
#  -0.14751570611865494,
#  0.17078250074273343,
#  0.01311143364965782,
#  -0.0019508756804964,
#  -0.2122979729686563,
#  -0.33624726877671207,
#  -0.052427618192057025,
#  -0.010594996333821632,
#  0.009655012494768932,
#  0.0005231974269023151,
#  -0.02266979906438601,
#  -0.20115145106312,
#  -0.31440360879906554,
#  -0.0571506170263359,
#  -0.02576676162633942,
#  -0.008036000739277266,
#  -0.025286512506598035,
#  -0.04160612715286755,
#  -0.2523699703431969,
#  -0.1738852361560453,
#  -0.01875219047694056,
#  -0.023656181949232864,
#  -0.2584073266706541,
#  -0.24583261674238005,
#  -0.05744213758138644,
#  0.09450943798528601,
#  0.09607068398812471,
#  0.07621677394213636,
#  -0.20423625363205591,
#  -0.10527856042926947,
#  0.11796840594360074,
#  -0.21738595264255342,
#  -0.3342011554529024,
#  -0.323229808581454,
#  -0.21761291070071825,
#  -0.23724624891505702,
#  -0.24506278699139228,
#  -0.25535460792504533,
#  -0.27856943629652137,
#  -0.39083547701363824,
#  -0.3928063066046704,
#  -0.19581971753369226,
#  -0.2635998935197429,
#  -0.2474045455948971,
#  -0.2464163002703971,
#  -0.28459380723836414,
#  -0.34535099441539124,
#  -0.3328549740729253,
#  -0.2862215095348659,
#  -0.24686267500366196,
#  -0.25838002597268106,
#  0.009653683732978854,
#  -0.06952738993960071,
#  -0.2430898104082915,
#  -0.15746197868923287,
#  -0.07112509934645411,
#  -0.16841872982285633,
#  0.07836951161155378,
#  0.05977325071618325,
#  -0.33471737378410177,
#  -0.11433413796096167,
#  0.05965868690463113,
#  -0.3136351275213007,
#  -0.23351458635877426,
#  -0.20821633899603742,
#  -0.23322876370037157,
#  -0.24010369104283863,
#  -0.2812697776748875,
#  -0.3100730045502922,
#  -0.18821545998891231,
#  -0.19300122173736828,
#  -0.20393481139993136,
#  -0.2107026459708848,
#  -0.20592695552703777,
#  -0.23821477298178678,
#  -0.267884945060931,
#  -0.19235057963898883,
#  -0.1844074156447927,
#  -0.1564484995963195,
#  -0.1707877655050779,
#  -0.2797052720141262,
#  0.0313273975946938,
#  -0.06236858255548804,
#  -0.28342316140655277,
#  -0.1908648810086771,
#  -0.09015492669965706,
#  -0.23293240725649542,
#  -0.008093116794907207,
#  -0.19412314095925726,
#  -0.137357018353346,
#  -0.16695757873553926,
#  -0.1519704494825373,
#  -0.11372713749026786,
#  -0.1352851551025831,
#  -0.12016915650513008,
#  -0.21999913707660987,
#  -0.28049545902696427,
#  -0.134545071633985,
#  -0.08796360930188564,
#  -0.08687830484637786,
#  -0.10090367355237703,
#  -0.15877448349993012,
#  -0.2328112963262336,
#  -0.25930391982213,
#  -0.1096724658270321,
#  -0.0526104506193569,
#  -0.05622419903614183,
#  -0.10104588447344368,
#  -0.15417442534220116,
#  -0.23221296504265393,
#  -0.2619176250138774,
#  -0.21148600097485404,
#  0.03211771162895875,
#  -0.06959916765312521,
#  -0.28313587126684403,
#  -0.19781510221598703,
#  -0.23561527511525476,
#  0.014629530451777464,
#  0.010502636596765674,
#  -0.2388391360249767,
#  -0.09556553832617705,
#  -0.13481609454885296,
#  -0.21020047864996655,
#  -0.19469519781512584,
#  -0.19921103873577756,
#  0.00022964222059021488,
#  0.07201068060842308,
#  0.12441422249345398,
#  0.10001690625422407,
#  0.003058434659465148,
#  -0.1871036615597858,
#  -0.21052721387142181,
#  0.006926240176087631,
#  0.08315514967341424,
#  0.09643892880513802,
#  0.06182688314166701,
#  0.009209288616813499,
#  -0.163505248303416,
#  -0.23420198781291773,
#  0.0541852653635274,
#  0.07805399755345757,
#  -0.03282116177729179,
#  0.02238449732320459,
#  -0.28758898593231413,
#  -0.2584198858621365,
#  -0.15574621178044878,
#  -0.23263380639980136,
#  0.10490324108276708,
#  0.019050166908549618,
#  0.04980530830249531,
#  -0.05190844081523326,
#  -0.27203808190629664,
#  0.021059903642687366,
#  0.004208132761643904,
#  0.040941443866183605,
#  0.1024020751150044,
#  0.11920432716435767,
#  0.07661370534186955,
#  -0.14403328109954247,
#  -0.26498291880630037,
#  -0.006726706770504229,
#  0.09152279723087081,
#  0.10069578427968068,
#  0.11236794779506083,
#  0.05478178749799832,
#  -0.13401646252486532,
#  -0.25617246776582114,
#  0.04217539991986523,
#  0.0948882309754629,
#  0.11621506292190463,
#  0.15677274844158925,
#  0.19259908905426243,
#  0.026144351825370962,
#  -0.21779370520787,
#  -0.3302958107949687,
#  -0.2715290476485891,
#  -0.19079593949739454,
#  -0.026703565532412883,
#  0.11681283015554272,
#  -0.1256161630214392,
#  0.07301646052818064,
#  -0.0865817493142374,
#  -0.3805456483188715,
#  0.01937751782608413,
#  0.012170349101234518,
#  0.019024378207154025,
#  -0.14077982530852873,
#  -0.2114877316814452,
#  -0.010243194578011088,
#  0.003238464582592554,
#  -0.024002862103483534,
#  -0.016759783506041473,
#  -0.06462221328778275,
#  -0.15890996913219213,
#  -0.2309461867591104,
#  0.05096668612523275,
#  0.0718370370549027,
#  0.09802552118297539,
#  0.1831271191819381,
#  0.09846024633622831,
#  -0.09149801579331508,
#  -0.1638105469483644,
#  0.08378354195314545,
#  0.05096184591519748,
#  -0.3220482550032363,
#  -0.12037605361565963,
#  -0.29532629963004886,
#  -0.24108061708937822,
#  0.03482534353629484,
#  0.15779623498653478,
#  -0.1953578712279399,
#  0.08192911901190535,
#  -0.09866020402508492,
#  -0.12744761551471784,
#  0.19492913794726208,
#  -0.20312340667752246,
#  0.06840891906274531,
#  0.1706969511991287,
#  0.13094436478327787,
#  0.1046897494236873,
#  0.1061711180158351,
#  -0.12842535354733212,
#  -0.2349289463860979,
#  0.07063250094223121,
#  0.08394838412798454,
#  0.0945612488440889,
#  0.047160678917402006,
#  0.045026792019714754,
#  -0.1973050483536823,
#  -0.30228383521778723,
#  -0.02091004053131349,
#  0.050217555631659916,
#  -0.012101819434561338,
#  0.054535895544254843,
#  0.0029672889223760143,
#  -0.11071737699367189,
#  -0.2766804092409695,
#  -0.2962547673283821,
#  0.08508133204608188,
#  0.10154170117553823,
#  -0.04017757896285135,
#  0.08365192368376351,
#  -0.2515150220328644,
#  -0.10749011157978755,
#  0.16530858672391974,
#  -0.02781639962696445,
#  -0.07893498382904336,
#  -0.011386327270287842,
#  -0.04305527451795292,
#  -0.2274682288113223,
#  -0.31624990985313667,
#  -0.08909836086849418,
#  -0.09310819614349895,
#  -0.1126589853627139,
#  -0.06549846163251279,
#  -0.09517520378650055,
#  -0.2869975408753063,
#  -0.3086341497971138,
#  -0.12555366754269442,
#  -0.08122334699716284,
#  -0.087478154379224,
#  -0.0790669385321781,
#  -0.11377277149927653,
#  -0.31213466782543153,
#  -0.18172291864142,
#  0.01423272843537339,
#  -0.12693944925487052,
#  -0.27484436320383765,
#  -0.18263924568618806,
#  -0.04306096847096899,
#  -0.13428388622436052,
#  0.017731453625478885,
#  0.05427761571603695,
#  -0.31227928272686317,
#  -0.09430453759184618,
#  0.04146615582469779,
#  -0.0915099163883495,
#  -0.2644927826284107,
#  -0.3498384697774752,
#  -0.095684607131401,
#  -0.06837057364207447,
#  -0.06476805592262416,
#  -0.07390006250672218,
#  -0.04942992716444765,
#  -0.20197208064250016,
#  -0.27849573900884733,
#  -0.0657412185970843,
#  -0.047173721242372804,
#  -0.05765522193458352,
#  -0.03328660434693456,
#  -0.021960022764972352,
#  -0.1886009554809875,
#  -0.26064684156520523,
#  0.015021598254382304,
#  -0.24133597662261713,
#  0.0038079049091939293,
#  -0.19246823799127996,
#  -0.3138599958451381,
#  -0.13610617673156228,
#  -0.10980385637314798,
#  -0.22348225420250217,
#  0.011977995986867038,
#  -0.13643789276280133,
#  -0.057338656124577475,
#  -0.07018577707887692,
#  -0.16390372255645916,
#  -0.20726140933377823,
#  0.005074100881673149,
#  0.03183091075375878,
#  0.04523877650453466,
#  0.036798404754966235,
#  0.021783612911469172,
#  -0.23323357025429914,
#  -0.3350273700495451,
#  -0.10115309345732446,
#  -0.08072608348639551,
#  -0.13926478159098193,
#  -0.3339879378506424,
#  -0.2988289348211145,
#  -0.3566382153720873,
#  -0.33539495851873535,
#  -0.16760234050596318,
#  -0.1606089448659867,
#  -0.23452441128917678,
#  -0.2813581972589038,
#  -0.31727172162790995,
#  -0.05280713740477079,
#  -0.09192889328055243,
#  -0.1539735191427958,
#  -0.28981776756325284,
#  -0.20090241972658035,
#  0.12141259896572897,
#  -0.2055333739103991,
#  0.007438012832442345,
#  -0.07392821767108335,
#  -0.2675211272056898,
#  0.16974301552959173,
#  0.04708098677636273,
#  0.12503294079325317,
#  0.1190909387424595,
#  -0.12203655103097531,
#  -0.21740010540948984,
#  0.09178767934428773,
#  0.09142346324977182,
#  0.08641271431146531,
#  0.009024222585778008,
#  -0.005399990522256176,
#  -0.18510336745832429,
#  -0.25971643836975467,
#  0.008757821510748831,
#  0.06530901357264644,
#  0.042123030814846835,
#  0.005800987677372041,
#  -0.041705030267094906,
#  -0.23800144823079006,
#  -0.2765565500715177,
#  -0.2446714866989638,
#  -0.021785624909089092,
#  -0.07575713121683919,
#  -0.22582621614337117,
#  -0.2652201530131368,
#  -0.2692117647900726,
#  0.08490044297736213,
#  0.02012973755780373,
#  -0.004707900285061961,
#  -0.2915072306406575,
#  0.04948878378885578,
#  0.1950619286748753,
#  -0.19675151465102209,
#  -0.1960183015151027,
#  -0.009779640780325387,
#  -0.010827730281888936,
#  -0.031623410790454935,
#  -0.073481962395627,
#  -0.07938968985471818,
#  -0.30356586275574743,
#  -0.410698540024882,
#  -0.12028551862060846,
#  -0.07270991699862714,
#  -0.08045595723428493,
#  -0.09105439428022555,
#  -0.10949719236004998,
#  -0.2858563619722586,
#  -0.32338583192342396,
#  -0.30396337676804497,
#  -0.03075952948791786,
#  -0.06400477909587017,
#  -0.29344357814973476,
#  -0.1689636335810858,
#  -0.15251546299055802,
#  -0.15170962946954597,
#  0.07867790924437683,
#  -0.0152828319801082,
#  -0.35873963236571627,
#  0.03790998751931769,
#  0.17640403882298683,
#  -0.30737440153636697,
#  -0.2973272835848969,
#  -0.13879339116141012,
#  -0.11715936107445221,
#  -0.09797562359648918,
#  -0.04769862324120131,
#  -0.04706719078189352,
#  -0.24110049079236445,
#  -0.25568607225824846,
#  -0.02822565749262857,
#  0.024553961300890853,
#  -0.047786976395444936,
#  -0.11210049005778389,
#  -0.15468017015941482,
#  -0.3029750215696497,
#  -0.38179637992993193,
#  -0.19739754219434044,
#  -0.1548744637735209,
#  -0.16463923531480618,
#  -0.10062011246386923,
#  -0.0733116829176199,
#  -0.04087222118938029,
#  -0.30678623559681534,
#  -0.11800964766464785,
#  -0.10098003507927437,
#  -0.2641783950330752,
#  0.06337362396541224,
#  -0.22147766750731349,
#  -0.10948033431631554,
#  0.005144575376216792,
#  -0.03338558867592322,
#  0.058266126638771176,
#  0.012702236856800553,
#  -0.04245760131037005,
#  -0.07668638074966022,
#  -0.246483990092417,
#  -0.2892989023981446,
#  -0.0004406441004919798,
#  0.03004051719141375,
#  -0.011190433885440637,
#  -0.07222339704113108,
#  -0.13818137074510028,
#  -0.26195002922871724,
#  -0.3359727516368887,
#  -0.17723339191096946,
#  -0.14658151827413088,
#  -0.10997365963177852,
#  -0.1267451371485927,
#  -0.10334272297376719,
#  -0.008490817757087432,
#  -0.06728641020193463,
#  -0.09411541144122014,
#  -0.33764507261332083,
#  -0.10608441751971727,
#  -0.25447445659402723,
#  0.02236007865404746,
#  0.03749126763997333,
#  -0.3516450787810134,
#  -0.0973978804426752,
#  -0.0435291125245101,
#  -0.13767350474370635,
#  -0.13697003113531708,
#  -0.16931532240571395,
#  -0.30480425819575996,
#  -0.34494414095034176,
#  -0.11979709205070666,
#  -0.14794980816690456,
#  -0.11692739379736636,
#  -0.1471649478224708,
#  -0.16229004069740594,
#  -0.31951344677288174,
#  -0.3476989736365048,
#  -0.18222505032310615,
#  -0.16370888497699831,
#  -0.1370525504195183,
#  -0.1247377005260738,
#  -0.1811221250803861,
#  -0.35011968613949684,
#  -0.35206206774917004,
#  -0.22125495466889367,
#  -0.10844187386682859,
#  -0.3214966158605721,
#  -0.2955113535833965,
#  -0.08754504957809357,
#  -0.07808579249352687,
#  -0.3017161714601131,
#  0.0629581881623341,
#  -0.04435863997604874,
#  -0.03644054778371112,
#  -0.07779285963303036,
#  -0.1640911093447262,
#  0.1422394324823087,
#  -0.3014842655300115,
#  -0.028058183294348754,
#  0.05768063867283832,
#  0.0744364646987936,
#  0.08343750394521186,
#  0.06389104628948529,
#  -0.17805902055842426,
#  -0.2479768843540857,
#  0.029264015284732076,
#  0.14237637685721402,
#  0.200061408589517,
#  0.2039501822625545,
#  0.13803888969619305,
#  -0.11758926378529738,
#  -0.19795303917427842,
#  0.09308484795771538,
#  0.15571880919642364,
#  0.15132412470988563,
#  0.0700884573695419,
#  -0.3857735247853128,
#  -0.338339924720125,
#  0.0016017953864583823,
#  -0.10136773851476333,
#  -0.10910508068454268,
#  0.1207344291087348,
#  -0.18700640475004965,
#  -0.004629379565099623,
#  -0.04979212875451058,
#  -0.3070165117013115,
#  0.18504181065483047,
#  0.0997576409557781,
#  0.044219151545328295,
#  0.042780194976502775,
#  0.02843557408942196,
#  -0.2056194982575827,
#  -0.29128051329340526,
#  0.012545123778208489,
#  0.11353884223642363,
#  0.12669096938541116,
#  0.1358536451512331,
#  0.14064769990375164,
#  -0.0874816145999347,
#  -0.24407906042038313,
#  0.09114115161918479,
#  0.16368995845941545,
#  0.17728650306486565,
#  0.19624235296845108,
#  0.18170722901060954,
#  -0.04527708225897228,
#  0.0920664094560026,
#  -0.09181015410911678,
#  -0.06433955136857387,
#  0.006504217871339299,
#  -0.2695757216005083,
#  -0.06077188647662449,
#  0.13990484441771472,
#  -0.24027429028603553,
#  -0.012600295828937347,
#  -0.09219378227302841,
#  -0.010658105272030607,
#  0.007620739796886045,
#  -0.03379155893113447,
#  -0.13530616512659888,
#  -0.1444867362188728,
#  -0.04854627181873425,
#  -0.12354284470224138,
#  -0.13553205267784535,
#  -0.1658601458813112,
#  -0.17792705670554376,
#  -0.2446051462398827,
#  -0.2729109197460161,
#  -0.08027401800413354,
#  -0.03885370681004532,
#  -0.0462852108596578,
#  -0.028462385408037555,
#  -0.04277779381093795,
#  -0.2529799023396253,
#  -0.3491391418249159,
#  -0.10457187669054761,
#  -0.02646879133196428,
#  -0.12355555340683638,
#  -0.011462147490626198,
#  -0.002127779556809359,
#  -0.06340760331130621,
#  -0.33288435738506333,
#  -0.03740421932903255,
#  0.07682516130635905,
#  -0.11374298075823336,
#  -0.003331350738440972,
#  -0.2767430176226464,
#  0.03271308247857285,
#  0.18379940007827028,
#  -0.06814563966605239,
#  0.025584352416643127,
#  0.09959110528281304,
#  0.014204720755042755,
#  -0.030783324813338626,
#  -0.2148183537253306,
#  -0.2560598726141407,
#  -0.015931892464010028,
#  0.008353920773293555,
#  -0.027449225332583455,
#  -0.06025476267971402,
#  -0.03682008799443336,
#  -0.2125710196783276,
#  -0.2836742820833862,
#  -0.0643697114062983,
#  -0.0185050523675465,
#  -0.01030290677012767,
#  -0.019222569566833908,
#  -0.204315291202386,
#  0.07514458947181071,
#  0.0031692685775001617,
#  -0.25228364959753813,
#  -0.17595116420861506,
#  -0.0658930781934249,
#  -0.1411821859104952,
#  -0.06867284421223852,
#  -0.019724711732962412,
#  -0.34117132501708963,
#  0.05616050613772966,
#  0.15679523703010026,
#  -0.022195100094691063,
#  0.005408530613881371,
#  -0.010600281623564384,
#  -0.2522209338369946,
#  -0.37043818241463833,
#  -0.10786189417859553,
#  -0.04714637213032443,
#  -0.05369018075666317,
#  -0.03059262192961474,
#  -0.061657902347878976,
#  -0.3033792750224134,
#  -0.3741205872485135,
#  -0.11289137455034023,
#  -0.04423369383385452,
#  -0.028608679422377783,
#  -0.05653867037153053,
#  -0.06069792371496212,
#  -0.22990766208451077,
#  -0.3381525519754033,
#  0.07581826778599128,
#  0.1354377043734189,
#  -0.051309533976112896,
#  -0.36548732993629696,
#  -0.12245224981482546,
#  -0.09044211399517536,
#  -0.26877378165254584,
#  -0.0065142368038350745,
#  -0.24149873521929816,
#  -0.10946135990160089,
#  -0.00868027296229587,
#  0.0004452035567535373,
#  -0.15637182717440726,
#  -0.2535814964308628,
#  0.07479994241110435,
#  0.1107879289024853,
#  0.07663880973786735,
#  0.04616865928008326,
#  0.07226934745820157,
#  -0.09484529714879193,
#  -0.15871888104694495,
#  0.04192267470024229,
#  0.1267167679781418,
#  0.20618870266655476,
#  0.22592550855454951,
#  0.23390812097124591,
#  -0.03811287021358328,
#  -0.1010221839865591,
#  0.1950769756392396,
#  0.22003773242259794,
#  0.03733100839533955,
#  0.0003914599320426482,
#  -0.060466115710823165,
#  -0.050682133181638375,
#  -0.08142319937874766,
#  -0.232020190340539,
#  0.06243492182619456,
#  0.013070135785993184,
#  -0.32235400073285886,
#  -0.05487947340473638,
#  0.010493923813896688,
#  -0.06790092469165424,
#  0.1952091359975877,
#  0.24912257217257958,
#  0.17980266379153165,
#  0.21428949195080788,
#  0.2302662270922782,
#  0.004115970590839332,
#  -0.03244969097491938,
#  0.273348887563157,
#  0.31357171712419923,
#  0.21423442751204153,
#  0.05102015671685735,
#  -0.12477531399984554,
#  -0.3104449262926128,
#  -0.33033404367101266,
#  -0.22671209331417952,
#  -0.2675519735710726,
#  -0.2800868735912654,
#  -0.3448553117914005]

# %%
print(np.mean(rmse))
# Out:
# 0.36382596527520256

# %% [markdown]
# # LSTM

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
def create_sliding_window(data, sequence_length, stride=1):
    X_list, y_list = [], []
    for i in range(len(data)):
      if (i + sequence_length) < len(data):
        X_list.append(data.iloc[i:i+sequence_length:stride, :].values)
        y_list.append(data.iloc[i+sequence_length, -1])
    return np.array(X_list), np.array(y_list)

train_split = 0.7
n_train = 1460
n_test = 732

features = ['total_aggregated']
feature_array = daily_data2[features].values

# Fit Scaler only on Training features
feature_scaler = MinMaxScaler()
feature_scaler.fit(feature_array[:n_train])
# Fit Scaler only on Training target values
target_scaler = MinMaxScaler(feature_range = (-1,1))
target_scaler.fit(feature_array[:n_train, -1].reshape(-1, 1))

# Transfom on both Training and Test data
scaled_array = pd.DataFrame(feature_scaler.transform(feature_array),
                            columns=features)

sequence_length = 1
X, y = create_sliding_window(scaled_array, 
                             sequence_length)

X_train = X[:n_train]
y_train = y[:n_train]

X_test = X[n_train:]
y_test = y[n_train:]

# %%
class BaseLSTM(nn.Module):

    def __init__(self, n_features, output_length, batch_size):

        super(BaseLSTM, self).__init__()

        self.batch_size = batch_size # user-defined

        self.hidden_size_1 = 256 # number of encoder cells (from paper)
        self.hidden_size_2 = 32 # number of decoder cells (from paper)
        self.stacked_layers = 2 # number of (stacked) LSTM layers for each stage
        self.dropout_probability = 0.5 # arbitrary value (the paper suggests that performance is generally stable across all ranges)

        self.lstm1 = nn.LSTM(n_features, 
                             self.hidden_size_1, 
                             num_layers=self.stacked_layers,
                             batch_first=True)
        self.lstm2 = nn.LSTM(self.hidden_size_1,
                             self.hidden_size_2,
                             num_layers=self.stacked_layers,
                             batch_first=True)
        
        self.fc = nn.Linear(self.hidden_size_2, output_length)
        self.loss_fn = nn.MSELoss()
        
    def forward(self, x):
        batch_size, seq_len, _ = x.size()

        hidden = self.init_hidden1(batch_size)
        output, _ = self.lstm1(x, hidden)
        state = self.init_hidden2(batch_size)
        output, state = self.lstm2(output, state)
        output = F.dropout(output, p=self.dropout_probability, training=True)
        output = output[:, -1, :] # take the last decoder cell's outputs
        y_pred = self.fc(output)
        return y_pred
        
    def init_hidden1(self, batch_size):
        hidden_state = Variable(torch.zeros(self.stacked_layers, batch_size, self.hidden_size_1))
        cell_state = Variable(torch.zeros(self.stacked_layers, batch_size, self.hidden_size_1))
        return hidden_state, cell_state
    
    def init_hidden2(self, batch_size):
        hidden_state = Variable(torch.zeros(self.stacked_layers, batch_size, self.hidden_size_2))
        cell_state = Variable(torch.zeros(self.stacked_layers, batch_size, self.hidden_size_2))
        return hidden_state, cell_state
    
    def loss(self, pred, truth):
        return self.loss_fn(pred, truth)

    def predict(self, X):
        return self(torch.tensor(X, dtype=torch.float32)).view(-1).detach().numpy()

# %%
n_features = scaled_array.shape[-1]
sequence_length = 1095
output_length = 1

batch_size = 256
n_epochs = 1
learning_rate = 0.01

base_lstm = BaseLSTM(n_features=n_features,
                             output_length=output_length,
                             batch_size = batch_size)

criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(base_lstm.parameters(), lr=learning_rate)

# %%
base_lstm.train()

for e in range(1, n_epochs+1):
    for b in range(0, len(X_train), batch_size):
        features = X_train[b:b+batch_size,:,:]
        target = y_train[b:b+batch_size]    

        X_batch = torch.tensor(features,dtype=torch.float32)    
        y_batch = torch.tensor(target,dtype=torch.float32)

        output = base_lstm(X_batch)
        loss = criterion(output.view(-1), y_batch)  

        loss.backward()
        optimizer.step()        
        optimizer.zero_grad() 

    if e % 1 == 0:
      print('epoch', e, 'loss: ', loss.item())
# Out:
# epoch 1 loss:  0.06664841622114182

# %%
norm_df = pd.DataFrame(norm_series, columns=(['total_scaled']))
norm_df['date'] = daily_data2.index

offset = sequence_length

def inverse_transform(y):
  return target_scaler.inverse_transform(y.reshape(-1, 1))
 
daily_data2['date'] = daily_data2.index

training_df = pd.DataFrame()
training_df['date'] = norm_df['date'].iloc[offset:n_train + offset:1] 
training_predictions = base_lstm.predict(X_train)
training_df['load'] = training_predictions #inverse_transform(training_predictions)
training_df['source'] = 'Training Prediction'

training_truth_df = pd.DataFrame()
training_truth_df['date'] = training_df['date']
training_truth_df['load'] = norm_df['total_scaled'].iloc[offset:n_train + offset:1] 
training_truth_df['source'] = 'True Values'

testing_df = pd.DataFrame()
testing_df['date'] = norm_df['date'].iloc[n_train + offset::1] 
testing_predictions = base_lstm.predict(X_test)
testing_df['load'] = testing_predictions  #inverse_transform(training_predictions)
testing_df['source'] = 'Test Prediction'

testing_truth_df = pd.DataFrame()
testing_truth_df['date'] = testing_df['date']
testing_truth_df['load'] = norm_df['total_scaled'].iloc[n_train + offset::1] 
testing_truth_df['source'] = 'True Values'

evaluation = pd.concat([training_df, 
                        testing_df,
                        training_truth_df,
                        testing_truth_df
                        ], axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[144], line 14
#      12 training_df['date'] = norm_df['date'].iloc[offset:n_train + offset:1]
#      13 training_predictions = base_lstm.predict(X_train)
# ---> 14 training_df['load'] = training_predictions #inverse_transform(training_predictions)
#      15 training_df['source'] = 'Training Prediction'
#      17 training_truth_df = pd.DataFrame()
#
# File c:\Users\loren\anaconda3\envs\thesis_packs\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File c:\Users\loren\anaconda3\envs\thesis_packs\lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
#    4181         # broadcast across multiple columns if necessary
#    4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\loren\anaconda3\envs\thesis_packs\lib\site-packages\pandas\core\frame.py:4915, in DataFrame._sanitize_column(self, value)
#    4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
# -> 4915     com.require_length_match(value, self.index)
#    4916 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File c:\Users\loren\anaconda3\envs\thesis_packs\lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (1460) does not match length of index (1097)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# %%
import plotly.express as px
fig = px.line(evaluation.loc[evaluation['date'].between('2016-01-01', '2021-12-31')],
                 x="date",
                 y="load",
                 color='source',
                 title="Energy Consumption in Wh vs Time")
fig.show()
