# %%
import datetime
import pandas as pd
import os
import numpy as np
from matplotlib import pyplot
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import seaborn as sns
import statsmodels.api as sm
import warnings

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller, kpss, ccf
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA 
from statsmodels.tsa.api import VAR 

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder,  MinMaxScaler, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Dropout, Flatten
import tensorflow_probability as tfp
from tensorflow_probability.python.distributions import Normal
tfb = tfp.bijectors
tfd = tfp.distributions

# %%
os.chdir('C:\\Users\\loren\\OneDrive - Università degli Studi di Milano\\Lezioni uni\\Tesi\\Dataset Energia\\')
path = 'Italy'

# %%
def retrieve_data(path):

    columns = ['Biomass  - Actual Aggregated [MW]',
       'Fossil Coal-derived gas  - Actual Aggregated [MW]',
       'Fossil Gas  - Actual Aggregated [MW]',
       'Fossil Hard coal  - Actual Aggregated [MW]',
       'Fossil Oil  - Actual Aggregated [MW]',
       'Geothermal  - Actual Aggregated [MW]',
       'Hydro Pumped Storage  - Actual Aggregated [MW]',
       'Hydro Run-of-river and poundage  - Actual Aggregated [MW]',
       'Hydro Water Reservoir  - Actual Aggregated [MW]',
       'Other  - Actual Aggregated [MW]', 'Solar  - Actual Aggregated [MW]',
       'Waste  - Actual Aggregated [MW]',
       'Wind Onshore  - Actual Aggregated [MW]', 'Time']

    # creo il vettore degli anni e il df vuoto dove appendere i singoli df
    years = [2016, 2017, 2018, 2019, 2020, 2021] # , 2022
    tot = pd.DataFrame()
    
    # carico i dati dei diversi anni
    for year in years:
        df = pd.read_csv(os.path.join(path, f"ITA{year}.csv"), parse_dates = ['MTU'])
        #df = df.reset_index()
        
        # aggiusto il formato della data in YYYY-MM-DD HH:mm:ss
        for i, row in df.iterrows():
            df["MTU"][i] = df['MTU'][i][:16]
        
        #df = df.drop_duplicates()
        
        df['Time'] = pd.to_datetime(df['MTU'], utc=True, infer_datetime_format=True)

        df.Time = df.Time.dt.strftime('%Y-%m-%d %H:%M:%S')

        df['Time'] = df['Time'].drop_duplicates()

        df = df[columns].sort_values(by=['Time'])
        
        # appendo i vari df a quello vuoto principale
        tot = pd.concat([tot, df], ignore_index=True)
    
    # imposto la data come indice
    tot = tot.set_index(pd.DatetimeIndex(tot['Time']))

    #tot.sort_index
    
    return tot
data = retrieve_data(path)
# Out:
# C:\Users\loren\AppData\Local\Temp\ipykernel_492\2830682557.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MTU"][i] = df['MTU'][i][:16]
# C:\Users\loren\AppData\Local\Temp\ipykernel_492\2830682557.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MTU"][i] = df['MTU'][i][:16]
# C:\Users\loren\AppData\Local\Temp\ipykernel_492\2830682557.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MTU"][i] = df['MTU'][i][:16]
# C:\Users\loren\AppData\Local\Temp\ipykernel_492\2830682557.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MTU"][i] = df['MTU'][i][:16]
# C:\Users\loren\AppData\Local\Temp\ipykernel_492\2830682557.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MTU"][i] = df['MTU'][i][:16]
# C:\Users\loren\AppData\Local\Temp\ipykernel_492\2830682557.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MTU"][i] = df['MTU'][i][:16]

# %%
print('There are {} missing values or NaNs in df_final.'.format(data.isnull().values.sum()))

data.interpolate(method='linear', limit_direction='forward', inplace=True, axis=0)
# Out:
# There are 2245 missing values or NaNs in df_final.

# %%
def data_and_aggregator(df):

    # seleziono tutte le colonne delle fonti energetiche
    columns = df.columns[ : df.shape[1]-1]

    # aggrego giornalmente i dati
    #daily_df = pd.DataFrame(df[columns].groupby([pd.Grouper(level='Time', freq='D')]).sum())

    # creo l'aggregato totale
    df['total_aggregated'] = df[columns].sum(axis=1)

    # aggrego i dati dell'idroelettrico
    hydro_cols = ['Hydro Pumped Storage  - Actual Aggregated [MW]',
       'Hydro Run-of-river and poundage  - Actual Aggregated [MW]',
       'Hydro Water Reservoir  - Actual Aggregated [MW]']
    
    df['hydro_tot'] = df[hydro_cols].sum(axis=1)

    # aggrego i dati del gas
    gas_cols = ['Fossil Coal-derived gas  - Actual Aggregated [MW]',
                'Fossil Gas  - Actual Aggregated [MW]']
    
    df['gas_tot'] = df[gas_cols].sum(axis=1)

    df = df.rename(columns={'Fossil Hard coal  - Actual Aggregated [MW]': 'hard_coal', 
                            'Fossil Oil  - Actual Aggregated [MW]': 'oil',
                            'Geothermal  - Actual Aggregated [MW]': 'geothermal',
                            'Waste  - Actual Aggregated [MW]': 'waste',
                            'Other  - Actual Aggregated [MW]': 'other',
                            'Solar  - Actual Aggregated [MW]' : 'solar',
                            'Wind Onshore  - Actual Aggregated [MW]' : 'wind',
                            'Biomass  - Actual Aggregated [MW]' : 'biomass'})
    
    df = df.drop(df[hydro_cols], axis = 1)
    df = df.drop(df[gas_cols], axis = 1)

    return df
data = data_and_aggregator(data)

# %%
# creo due dunzioni: una per i weekend (quando sabato/domenica è 1, altrimenti 0) e l'altra per le vacanze (1/1, 25/4, 1/5, 2/6, 15/8, 25/12)
def businesshour_and_we_generation(df):
    # Generate 'weekend' feature
    for i in range(len(df)):
        position = df.index[i]
        hour = position.hour
        weekend = position.weekday()
        df.loc[position, 'weekend'] = weekend
        df.loc[position, 'hour'] = hour
        
        if (weekend == 5):
            df.loc[position, 'saturday'] = 1
            df.loc[position, 'weekend'] = 1
        elif (weekend == 6):
            df.loc[position, 'sunday'] = 1
            df.loc[position, 'weekend'] = 2
        else:
            df.loc[position, 'saturday'] = 0
            df.loc[position, 'sunday'] = 0
            df.loc[position, 'weekend'] = 0
            
        if (hour >= 8 and hour <= 18):
            df.loc[position, 'business hour'] = 1
        else:
            df.loc[position, 'business hour'] = 0

    df.saturday = df.saturday.fillna(0)
    df.sunday = df.sunday.fillna(0)

    return df

data = businesshour_and_we_generation(data)

# %%
data = data.dropna()

# %% [markdown]
# # LSTM

# %%
def create_sliding_window(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
def plot_model_rmse_and_loss(history):
    
    #evaluating train and validation accuracies and losses
    
    train_rmse = history.history['root_mean_squared_error']
    #val_rmse = history.history['val_root_mean_squared_error']
    
    train_loss = history.history['loss']
    #val_loss = history.history['val_loss']
    
    #visualizing epochs vs. train and validation accuracies and losses
    
    plt.figure(figsize=(20, 10))
    plt.subplot(1, 2, 1)
    plt.plot(train_rmse, label='Training RMSE')
    #plt.plot(val_rmse, label='Validation RMSE')
    plt.legend()
    plt.title('Epochs vs. Training and Validation RMSE')
    
    plt.subplot(1, 2, 2)
    plt.plot(train_loss, label='Training Loss')
    #plt.plot(val_loss, label='Validation Loss')
    plt.legend()
    plt.title('Epochs vs. Training and Validation Loss')

    plt.show()

def plot_preds_vs_actual(true, preds):
    plt.figure(figsize=(12,6))
    plt.plot(true, label='Real')
    plt.plot(preds, label='Predicted')
    plt.title('Predicted vs Real Values')
    plt.title('Actual vs Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Total Aggregated')
    plt.legend()
    plt.show()

# %%
# (1)
#def create_sliding_window(data, window_size):
#    X = []
#    y = []
#    for i in range(len(data)-window_size-1):
#        X.append(data[i:i+window_size])
#        y.append(data[i+window_size])
#    return np.array(X), np.array(y)

# %%
#train_split = 0.7
n_train = 35064
n_test = int(len(data)-n_train)
sequence_length = 24

features = ['total_aggregated']
n_features = len(features)
feature_array = data[features].values

# (2)
# Fit Scaler only on Training target values
target_scaler = StandardScaler()
target_scaler.fit(feature_array[:n_train].reshape(-1,1))

# Transfom on both Training and Test data
scaled_array = target_scaler.transform(feature_array)


X_train, y_train = create_sliding_window(scaled_array[:n_train], sequence_length)
X_test, y_test = create_sliding_window(scaled_array[n_train:], sequence_length)

# %%
input_shape = X_train.shape[-2:]

loss = tf.keras.losses.MeanSquaredError()

metric = [tf.keras.metrics.RootMeanSquaredError()]

#lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch / 10))

early_stopping = tf.keras.callbacks.EarlyStopping(patience=3)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.003)

# %%
tf.keras.backend.clear_session()

#model building

lstm = tf.keras.Sequential([
    tf.keras.layers.LSTM(64, return_sequences=True, input_shape=input_shape),
    #tf.keras.layers.LSTM(64, return_sequences=True),
    #tf.keras.layers.BatchNormalization(),
    #tf.keras.layers.Dropout(0.5),
    #tf.keras.layers.LSTM(128, return_sequences=True),
    #tf.keras.layers.BatchNormalization(),
    #tf.keras.layers.Dropout(0.5),
    #tf.keras.layers.LSTM(64, return_sequences=True),
    #tf.keras.layers.Dropout(0.5),
    #tf.keras.layers.LSTM(32, return_sequences=True),
    #tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(1),
])

lstm.compile(loss=loss, optimizer=optimizer, metrics=metric)

# %%
history = lstm.fit(X_train, y_train, epochs=100, batch_size=168) # , callbacks=[early_stopping], validation_data=[X_test, y_test],
# Out:
# Epoch 1/100
# 209/209 [==============================] - 13s 38ms/step - loss: 0.0776 - root_mean_squared_error: 0.2786
# Epoch 2/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0220 - root_mean_squared_error: 0.1482
# Epoch 3/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0200 - root_mean_squared_error: 0.1413
# Epoch 4/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0189 - root_mean_squared_error: 0.1373
# Epoch 5/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0183 - root_mean_squared_error: 0.1351
# Epoch 6/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341
# Epoch 7/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0176 - root_mean_squared_error: 0.1326
# Epoch 8/100
# 209/209 [==============================] - 7s 36ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327
# Epoch 9/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0174 - root_mean_squared_error: 0.1318
# Epoch 10/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0171 - root_mean_squared_error: 0.1306
# Epoch 11/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297
# Epoch 12/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0166 - root_mean_squared_error: 0.1289
# Epoch 13/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280
# Epoch 14/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268
# Epoch 15/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0161 - root_mean_squared_error: 0.1270
# Epoch 16/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264
# Epoch 17/100
# 209/209 [==============================] - 9s 45ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264
# Epoch 18/100
# 209/209 [==============================] - 10s 47ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257
# Epoch 19/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0155 - root_mean_squared_error: 0.1246
# Epoch 20/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0155 - root_mean_squared_error: 0.1247
# Epoch 21/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0158 - root_mean_squared_error: 0.1255
# Epoch 22/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0153 - root_mean_squared_error: 0.1237
# Epoch 23/100
# 209/209 [==============================] - 7s 36ms/step - loss: 0.0155 - root_mean_squared_error: 0.1243
# Epoch 24/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0154 - root_mean_squared_error: 0.1239
# Epoch 25/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0148 - root_mean_squared_error: 0.1219
# Epoch 26/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0150 - root_mean_squared_error: 0.1223
# Epoch 27/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211
# Epoch 28/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211
# Epoch 29/100
# 209/209 [==============================] - 11s 52ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209
# Epoch 30/100
# 209/209 [==============================] - 10s 47ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199
# Epoch 31/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205
# Epoch 32/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195
# Epoch 33/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201
# Epoch 34/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195
# Epoch 35/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 36/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0143 - root_mean_squared_error: 0.1195
# Epoch 37/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0140 - root_mean_squared_error: 0.1184
# Epoch 38/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182
# Epoch 39/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179
# Epoch 40/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182
# Epoch 41/100
# 209/209 [==============================] - 9s 43ms/step - loss: 0.0140 - root_mean_squared_error: 0.1183
# Epoch 42/100
# 209/209 [==============================] - 10s 50ms/step - loss: 0.0138 - root_mean_squared_error: 0.1173
# Epoch 43/100
# 209/209 [==============================] - 10s 49ms/step - loss: 0.0136 - root_mean_squared_error: 0.1164
# Epoch 44/100
# 209/209 [==============================] - 11s 51ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165
# Epoch 45/100
# 209/209 [==============================] - 11s 55ms/step - loss: 0.0136 - root_mean_squared_error: 0.1167
# Epoch 46/100
# 209/209 [==============================] - 12s 56ms/step - loss: 0.0135 - root_mean_squared_error: 0.1163
# Epoch 47/100
# 209/209 [==============================] - 12s 59ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162
# Epoch 48/100
# 209/209 [==============================] - 12s 57ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165
# Epoch 49/100
# 209/209 [==============================] - 12s 55ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157
# Epoch 50/100
# 209/209 [==============================] - 11s 54ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157
# Epoch 51/100
# 209/209 [==============================] - 12s 55ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147
# Epoch 52/100
# 209/209 [==============================] - 11s 54ms/step - loss: 0.0133 - root_mean_squared_error: 0.1154
# Epoch 53/100
# 209/209 [==============================] - 11s 54ms/step - loss: 0.0131 - root_mean_squared_error: 0.1145
# Epoch 54/100
# 209/209 [==============================] - 12s 56ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147
# Epoch 55/100
# 209/209 [==============================] - 12s 56ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144
# Epoch 56/100
# 209/209 [==============================] - 11s 55ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141
# Epoch 57/100
# 209/209 [==============================] - 11s 53ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144
# Epoch 58/100
# 209/209 [==============================] - 12s 56ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141
# Epoch 59/100
# 209/209 [==============================] - 11s 52ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139
# Epoch 60/100
# 209/209 [==============================] - 10s 49ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131
# Epoch 61/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141
# Epoch 62/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133
# Epoch 63/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136
# Epoch 64/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127
# Epoch 65/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133
# Epoch 66/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0126 - root_mean_squared_error: 0.1125
# Epoch 67/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121
# Epoch 68/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118
# Epoch 69/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122
# Epoch 70/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115
# Epoch 71/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113
# Epoch 72/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108
# Epoch 73/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115
# Epoch 74/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0123 - root_mean_squared_error: 0.1107
# Epoch 75/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108
# Epoch 76/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101
# Epoch 77/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0122 - root_mean_squared_error: 0.1103
# Epoch 78/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099
# Epoch 79/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098
# Epoch 80/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0121 - root_mean_squared_error: 0.1098
# Epoch 81/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0120 - root_mean_squared_error: 0.1095
# Epoch 82/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085
# Epoch 83/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089
# Epoch 84/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090
# Epoch 85/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082
# Epoch 86/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0118 - root_mean_squared_error: 0.1088
# Epoch 87/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0117 - root_mean_squared_error: 0.1079
# Epoch 88/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077
# Epoch 89/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0116 - root_mean_squared_error: 0.1078
# Epoch 90/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073
# Epoch 91/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076
# Epoch 92/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063
# Epoch 93/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069
# Epoch 94/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058
# Epoch 95/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060
# Epoch 96/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0113 - root_mean_squared_error: 0.1062
# Epoch 97/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058
# Epoch 98/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053
# Epoch 99/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0111 - root_mean_squared_error: 0.1054
# Epoch 100/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0110 - root_mean_squared_error: 0.1047

# %%
plot_model_rmse_and_loss(history)

# %%
predictions = lstm.predict(X_test)
predictions_tot_scaled = target_scaler.inverse_transform(predictions)
# Out:
# 548/548 [==============================] - 5s 7ms/step

# %%
truth = pd.Series(feature_array[-len(predictions):].flatten())
res=pd.DataFrame()
res['y_true'] = truth
res['y_pred'] = predictions_tot_scaled

rmse_tot = sqrt(np.mean((res.y_true - res.y_pred)**2))
print('Mean Squared Error:', rmse_tot)
# Out:
# Mean Squared Error: 935.4534037577413

# %%
plot_preds_vs_actual(truth, predictions_tot_scaled)

# %%
#scaled_predictions = target_scaler.transform(predictions)
#scaled_truth = target_scaler.transform(truth)
#
#scaled_mse = sqrt(np.mean((scaled_predictions - scaled_truth)**2))
#print('Mean Squared Error:', scaled_mse)

# %% [markdown]
# ## Forecast with dummy variables for saturday and sunday

# %%
#train_split = 0.7
n_train = 35067
n_test = int(len(data)-n_train)

features = ['total_aggregated']
sat = ['saturday']
sun = ['sunday']

feature_array = data[features].values
#dummy = data[we].values
dummy_1 = data[sat].values
dummy_2 = data[sun].values
dummies = [dummy_1, dummy_2]

## concatenate dummy variables with feature_array
#feature_array = np.concatenate((feature_array, dummy_array), axis=1)

# %%
# Fit Scaler only on Training target values
target_scaler = StandardScaler()

# Transfom on both Training and Test data
target_scaler.fit(feature_array[:n_train].reshape(-1,1))
scaled_array = target_scaler.transform(feature_array)

# %%
# concatenate dummy variables with feature_array
final_array = np.concatenate((scaled_array, dummy_1), axis=1)
final_array = np.concatenate((final_array, dummy_2), axis=1)

# %%
sequence_length = 24
#n_features = 3
X, y = create_sliding_window(final_array, sequence_length)

# %%
# Then, split into train and test
X_train = X[:n_train]
y_train = y[:n_train, 0]  # Select only the first column (the scaled feature values)

X_test = X[n_train:]
y_test = y[n_train:, 0]  # Select only the first column (the scaled feature values)

# %%
input_shape = X_train.shape[-2:]
loss = tf.keras.losses.MeanSquaredError()
metric = [tf.keras.metrics.RootMeanSquaredError()]
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch / 10))
early_stopping = tf.keras.callbacks.EarlyStopping(patience=3)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.003)

# %%
tf.keras.backend.clear_session()

#model building

lstm2 = tf.keras.Sequential([
    tf.keras.layers.LSTM(64, return_sequences=True, input_shape=input_shape),
    #tf.keras.layers.LSTM(128, return_sequences=True),
    #tf.keras.layers.BatchNormalization(),
    #tf.keras.layers.Dropout(0.5),
    #tf.keras.layers.LSTM(64, return_sequences=True),
    #tf.keras.layers.Dropout(0.5),
    #tf.keras.layers.LSTM(32, return_sequences=True),
    #tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(1),
])

lstm2.compile(loss=loss, optimizer=optimizer, metrics=metric)

# %%
history2 = lstm2.fit(X_train, y_train, epochs=100, batch_size=168) #validation_data=[X_test, y_test]
# Out:
# Epoch 1/100
# 209/209 [==============================] - 13s 52ms/step - loss: 0.0731 - root_mean_squared_error: 0.2704
# Epoch 2/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0212 - root_mean_squared_error: 0.1455
# Epoch 3/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0191 - root_mean_squared_error: 0.1381
# Epoch 4/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0185 - root_mean_squared_error: 0.1360
# Epoch 5/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0181 - root_mean_squared_error: 0.1346
# Epoch 6/100
# 209/209 [==============================] - 9s 42ms/step - loss: 0.0177 - root_mean_squared_error: 0.1329
# Epoch 7/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325
# Epoch 8/100
# 209/209 [==============================] - 7s 36ms/step - loss: 0.0169 - root_mean_squared_error: 0.1302
# Epoch 9/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0166 - root_mean_squared_error: 0.1290
# Epoch 10/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0167 - root_mean_squared_error: 0.1293
# Epoch 11/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0162 - root_mean_squared_error: 0.1274
# Epoch 12/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0161 - root_mean_squared_error: 0.1269
# Epoch 13/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273
# Epoch 14/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254
# Epoch 15/100
# 209/209 [==============================] - 8s 36ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252
# Epoch 16/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0157 - root_mean_squared_error: 0.1255
# Epoch 17/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0154 - root_mean_squared_error: 0.1240
# Epoch 18/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0154 - root_mean_squared_error: 0.1239
# Epoch 19/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0153 - root_mean_squared_error: 0.1235
# Epoch 20/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227
# Epoch 21/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226
# Epoch 22/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221
# Epoch 23/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221
# Epoch 24/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0147 - root_mean_squared_error: 0.1212
# Epoch 25/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0146 - root_mean_squared_error: 0.1210
# Epoch 26/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0145 - root_mean_squared_error: 0.1206
# Epoch 27/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0145 - root_mean_squared_error: 0.1202
# Epoch 28/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 29/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0142 - root_mean_squared_error: 0.1194
# Epoch 30/100
# 209/209 [==============================] - 12s 58ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190
# Epoch 31/100
# 209/209 [==============================] - 13s 62ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 32/100
# 209/209 [==============================] - 14s 65ms/step - loss: 0.0140 - root_mean_squared_error: 0.1182
# Epoch 33/100
# 209/209 [==============================] - 12s 57ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171
# Epoch 34/100
# 209/209 [==============================] - 13s 61ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170
# Epoch 35/100
# 209/209 [==============================] - 13s 61ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 36/100
# 209/209 [==============================] - 13s 64ms/step - loss: 0.0138 - root_mean_squared_error: 0.1173
# Epoch 37/100
# 209/209 [==============================] - 15s 70ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178
# Epoch 38/100
# 209/209 [==============================] - 13s 63ms/step - loss: 0.0137 - root_mean_squared_error: 0.1169
# Epoch 39/100
# 209/209 [==============================] - 14s 65ms/step - loss: 0.0135 - root_mean_squared_error: 0.1164
# Epoch 40/100
# 209/209 [==============================] - 12s 59ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161
# Epoch 41/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0134 - root_mean_squared_error: 0.1156
# Epoch 42/100
# 209/209 [==============================] - 6s 29ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152
# Epoch 43/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0132 - root_mean_squared_error: 0.1147
# Epoch 44/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0131 - root_mean_squared_error: 0.1144
# Epoch 45/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153
# Epoch 46/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0129 - root_mean_squared_error: 0.1138
# Epoch 47/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139
# Epoch 48/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131
# Epoch 49/100
# 209/209 [==============================] - 7s 36ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133
# Epoch 50/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122
# Epoch 51/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123
# Epoch 52/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127
# Epoch 53/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119
# Epoch 54/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109
# Epoch 55/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0124 - root_mean_squared_error: 0.1114
# Epoch 56/100
# 209/209 [==============================] - 7s 36ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106
# Epoch 57/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0122 - root_mean_squared_error: 0.1107
# Epoch 58/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0121 - root_mean_squared_error: 0.1102
# Epoch 59/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099
# Epoch 60/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0120 - root_mean_squared_error: 0.1094
# Epoch 61/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0118 - root_mean_squared_error: 0.1089
# Epoch 62/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087
# Epoch 63/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087
# Epoch 64/100
# 209/209 [==============================] - 8s 36ms/step - loss: 0.0118 - root_mean_squared_error: 0.1084
# Epoch 65/100
# 209/209 [==============================] - 8s 36ms/step - loss: 0.0117 - root_mean_squared_error: 0.1080
# Epoch 66/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073
# Epoch 67/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070
# Epoch 68/100
# 209/209 [==============================] - 6s 29ms/step - loss: 0.0114 - root_mean_squared_error: 0.1066
# Epoch 69/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0114 - root_mean_squared_error: 0.1066
# Epoch 70/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064
# Epoch 71/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050
# Epoch 72/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056
# Epoch 73/100
# 209/209 [==============================] - 7s 36ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049
# Epoch 74/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0109 - root_mean_squared_error: 0.1045
# Epoch 75/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044
# Epoch 76/100
# 209/209 [==============================] - 9s 42ms/step - loss: 0.0109 - root_mean_squared_error: 0.1044
# Epoch 77/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039
# Epoch 78/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038
# Epoch 79/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028
# Epoch 80/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033
# Epoch 81/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020
# Epoch 82/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0105 - root_mean_squared_error: 0.1026
# Epoch 83/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019
# Epoch 84/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014
# Epoch 85/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0102 - root_mean_squared_error: 0.1010
# Epoch 86/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0101 - root_mean_squared_error: 0.1007
# Epoch 87/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0100 - root_mean_squared_error: 0.0999
# Epoch 88/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0100 - root_mean_squared_error: 0.0999
# Epoch 89/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0102 - root_mean_squared_error: 0.1011
# Epoch 90/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987
# Epoch 91/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0099 - root_mean_squared_error: 0.0993
# Epoch 92/100
# 209/209 [==============================] - 8s 39ms/step - loss: 0.0099 - root_mean_squared_error: 0.0994
# Epoch 93/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984
# Epoch 94/100
# 209/209 [==============================] - 6s 29ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984
# Epoch 95/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0095 - root_mean_squared_error: 0.0977
# Epoch 96/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0094 - root_mean_squared_error: 0.0972
# Epoch 97/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0095 - root_mean_squared_error: 0.0976
# Epoch 98/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0094 - root_mean_squared_error: 0.0970
# Epoch 99/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0093 - root_mean_squared_error: 0.0966
# Epoch 100/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0093 - root_mean_squared_error: 0.0965

# %%
plot_model_rmse_and_loss(history2)

# %%
predictions2 = lstm2.predict(X_test)
predictions2_scaled = target_scaler.inverse_transform(predictions2)
# Out:
# 548/548 [==============================] - 4s 7ms/step

# %%
truth2 = pd.Series(feature_array[-len(predictions2):].flatten())
res2=pd.DataFrame()
res2['y_true'] = truth2
res2['y_pred'] = predictions2_scaled

# %%
rmse2 = sqrt(np.mean((res2.y_true - res2.y_pred)**2))
print('Mean Squared Error:', rmse2)
# Out:
# Mean Squared Error: 924.8478189417201

# %%
plot_preds_vs_actual(res2.y_pred, res.y_true)

# %% [markdown]
# # Forecast with business hour dummy

# %%
# il 2020 inizia a inidce 35068

features = ['total_aggregated']
dummy_features = ['business hour']

feature_array = data[features].values
dummy_array = data[dummy_features].values

## concatenate dummy variables with feature_array
#feature_array = np.concatenate((feature_array, dummy_array), axis=1)

# Fit Scaler only on Training target values
target_scaler = StandardScaler()
target_scaler.fit(feature_array[:n_train].reshape(-1,1))

# Transfom on both Training and Test data
scaled_array = target_scaler.transform(feature_array)

# concatenate dummy variables with feature_array
final_array = np.concatenate((scaled_array, dummy_array), axis=1)

sequence_length = 24
#X_train, y_train = create_sliding_window(final_array[:n_train], sequence_length)
#X_test, y_test = create_sliding_window(final_array[n_train:], sequence_length)

# %%
sequence_length = 24
#n_features = 3
X, y = create_sliding_window(final_array, sequence_length)
# Then, split into train and test
X_train = X[:n_train]
y_train = y[:n_train, 0]  # Select only the first column (the scaled feature values)

X_test = X[n_train:]
y_test = y[n_train:, 0]  # Select only the first column (the scaled feature values)

# %%
input_shape = X_train.shape[-2:]
loss = tf.keras.losses.MeanSquaredError()
metric = [tf.keras.metrics.RootMeanSquaredError()]
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
              lambda epoch: 1e-4 * 10**(epoch / 10))
early_stopping = tf.keras.callbacks.EarlyStopping(patience=20)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.003)

tf.keras.backend.clear_session()

# %%
#model building

lstm3 = tf.keras.Sequential([
    tf.keras.layers.LSTM(64, return_sequences=True, input_shape=input_shape),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1),
])

lstm3.compile(loss=loss, optimizer=optimizer, metrics=metric)

# %%
history3 = lstm3.fit(X_train, y_train, epochs=100, batch_size=168) #validation_data=[X_test, y_test]
plot_model_rmse_and_loss(history3)

predictions3 = lstm3.predict(X_test)
predictions3_scaled = target_scaler.inverse_transform(predictions3)
# Out:
# Epoch 1/100
# 209/209 [==============================] - 6s 20ms/step - loss: 0.1022 - root_mean_squared_error: 0.3197
# Epoch 2/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0268 - root_mean_squared_error: 0.1638
# Epoch 3/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0208 - root_mean_squared_error: 0.1441
# Epoch 4/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0199 - root_mean_squared_error: 0.1411
# Epoch 5/100
# 209/209 [==============================] - 6s 28ms/step - loss: 0.0188 - root_mean_squared_error: 0.1373
# Epoch 6/100
# 209/209 [==============================] - 6s 27ms/step - loss: 0.0184 - root_mean_squared_error: 0.1355
# Epoch 7/100
# 209/209 [==============================] - 6s 29ms/step - loss: 0.0181 - root_mean_squared_error: 0.1345
# Epoch 8/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0176 - root_mean_squared_error: 0.1327
# Epoch 9/100
# 209/209 [==============================] - 6s 29ms/step - loss: 0.0173 - root_mean_squared_error: 0.1314
# Epoch 10/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301
# Epoch 11/100
# 209/209 [==============================] - 6s 27ms/step - loss: 0.0169 - root_mean_squared_error: 0.1301
# Epoch 12/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0163 - root_mean_squared_error: 0.1278
# Epoch 13/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283
# Epoch 14/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283
# Epoch 15/100
# 209/209 [==============================] - 6s 29ms/step - loss: 0.0163 - root_mean_squared_error: 0.1276
# Epoch 16/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273
# Epoch 17/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0160 - root_mean_squared_error: 0.1266
# Epoch 18/100
# 209/209 [==============================] - 8s 36ms/step - loss: 0.0159 - root_mean_squared_error: 0.1263
# Epoch 19/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0156 - root_mean_squared_error: 0.1250
# Epoch 20/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0156 - root_mean_squared_error: 0.1251
# Epoch 21/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248
# Epoch 22/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252
# Epoch 23/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0154 - root_mean_squared_error: 0.1242
# Epoch 24/100
# 209/209 [==============================] - 6s 28ms/step - loss: 0.0153 - root_mean_squared_error: 0.1237
# Epoch 25/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0154 - root_mean_squared_error: 0.1239
# Epoch 26/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0152 - root_mean_squared_error: 0.1231
# Epoch 27/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218
# Epoch 28/100
# 209/209 [==============================] - 6s 29ms/step - loss: 0.0150 - root_mean_squared_error: 0.1226
# Epoch 29/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0152 - root_mean_squared_error: 0.1231
# Epoch 30/100
# 209/209 [==============================] - 8s 36ms/step - loss: 0.0148 - root_mean_squared_error: 0.1215
# Epoch 31/100
# 209/209 [==============================] - 7s 35ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221
# Epoch 32/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221
# Epoch 33/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214
# Epoch 34/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0146 - root_mean_squared_error: 0.1206
# Epoch 35/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0146 - root_mean_squared_error: 0.1206
# Epoch 36/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0146 - root_mean_squared_error: 0.1208
# Epoch 37/100
# 209/209 [==============================] - 9s 42ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199
# Epoch 38/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0147 - root_mean_squared_error: 0.1211
# Epoch 39/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0144 - root_mean_squared_error: 0.1200
# Epoch 40/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 41/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205
# Epoch 42/100
# 209/209 [==============================] - 6s 28ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193
# Epoch 43/100
# 209/209 [==============================] - 6s 27ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191
# Epoch 44/100
# 209/209 [==============================] - 6s 28ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190
# Epoch 45/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0142 - root_mean_squared_error: 0.1192
# Epoch 46/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0141 - root_mean_squared_error: 0.1186
# Epoch 47/100
# 209/209 [==============================] - 6s 29ms/step - loss: 0.0139 - root_mean_squared_error: 0.1179
# Epoch 48/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180
# Epoch 49/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188
# Epoch 50/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0138 - root_mean_squared_error: 0.1175
# Epoch 51/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180
# Epoch 52/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178
# Epoch 53/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0137 - root_mean_squared_error: 0.1170
# Epoch 54/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0135 - root_mean_squared_error: 0.1164
# Epoch 55/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178
# Epoch 56/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171
# Epoch 57/100
# 209/209 [==============================] - 6s 29ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166
# Epoch 58/100
# 209/209 [==============================] - 6s 30ms/step - loss: 0.0136 - root_mean_squared_error: 0.1165
# Epoch 59/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0135 - root_mean_squared_error: 0.1164
# Epoch 60/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161
# Epoch 61/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161
# Epoch 62/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0136 - root_mean_squared_error: 0.1166
# Epoch 63/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0133 - root_mean_squared_error: 0.1154
# Epoch 64/100
# 209/209 [==============================] - 7s 31ms/step - loss: 0.0134 - root_mean_squared_error: 0.1157
# Epoch 65/100
# 209/209 [==============================] - 7s 32ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153
# Epoch 66/100
# 209/209 [==============================] - 6s 31ms/step - loss: 0.0133 - root_mean_squared_error: 0.1151
# Epoch 67/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152
# Epoch 68/100
# 209/209 [==============================] - 7s 34ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152
# Epoch 69/100
# 209/209 [==============================] - 7s 33ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146
# Epoch 70/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146
# Epoch 71/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140
# Epoch 72/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136
# Epoch 73/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0130 - root_mean_squared_error: 0.1140
# Epoch 74/100
# 209/209 [==============================] - 9s 41ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141
# Epoch 75/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134
# Epoch 76/100
# 209/209 [==============================] - 8s 36ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131
# Epoch 77/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135
# Epoch 78/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0130 - root_mean_squared_error: 0.1138
# Epoch 79/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0127 - root_mean_squared_error: 0.1126
# Epoch 80/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134
# Epoch 81/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131
# Epoch 82/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121
# Epoch 83/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127
# Epoch 84/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0126 - root_mean_squared_error: 0.1125
# Epoch 85/100
# 209/209 [==============================] - 7s 36ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121
# Epoch 86/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0126 - root_mean_squared_error: 0.1123
# Epoch 87/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124
# Epoch 88/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0125 - root_mean_squared_error: 0.1119
# Epoch 89/100
# 209/209 [==============================] - 10s 46ms/step - loss: 0.0126 - root_mean_squared_error: 0.1121
# Epoch 90/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115
# Epoch 91/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0124 - root_mean_squared_error: 0.1112
# Epoch 92/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108
# Epoch 93/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0123 - root_mean_squared_error: 0.1107
# Epoch 94/100
# 209/209 [==============================] - 8s 38ms/step - loss: 0.0122 - root_mean_squared_error: 0.1105
# Epoch 95/100
# 209/209 [==============================] - 7s 36ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101
# Epoch 96/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0121 - root_mean_squared_error: 0.1102
# Epoch 97/100
# 209/209 [==============================] - 8s 40ms/step - loss: 0.0121 - root_mean_squared_error: 0.1101
# Epoch 98/100
# 209/209 [==============================] - 8s 41ms/step - loss: 0.0123 - root_mean_squared_error: 0.1107
# Epoch 99/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100
# Epoch 100/100
# 209/209 [==============================] - 8s 37ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099
# 548/548 [==============================] - 5s 7ms/step

# %%
truth = data['total_aggregated'].values
truth = truth[-len(predictions3):]

rmse3 = sqrt(np.mean((predictions3_scaled - truth)**2))
print('Mean Squared Error:', rmse3)

#scaled_predictions = target_scaler.transform(predictions3)
#scaled_truth = target_scaler.transform(truth.reshape(-1,1))
#
#scaled_mse = sqrt(np.mean((scaled_predictions - scaled_truth)**2))
#print('Mean Squared Error:', scaled_mse)
# Out:
# Mean Squared Error: 13204.369280027002

# %%
plt.figure(figsize=(12,6))
plt.plot(truth, label='Real')
plt.plot(predictions3_scaled, label='Predicted')
plt.title('Predicted vs Real Values')
plt.title('Actual vs Predicted Values')
plt.xlabel('Time')
plt.ylabel('Total Aggregated')
plt.legend()
plt.show()
